# %%
import torchvision 
import torch
from torch.utils.data import Dataset
from torchvision import datasets
import torchvision.transforms as transforms   
import torch.optim as optim
from torchvision.transforms import RandomRotation
from torchvision.transforms import Pad
from torchvision.transforms import Resize
from torchvision.transforms import ToTensor
from torchvision.transforms import Compose
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
from PIL import Image
from numpy.linalg import norm
from torch.cuda.random import device_count
from torchvision.datasets import CIFAR10
from torch.utils.data import random_split
import torch.optim as optim
import torchvision.transforms as transforms 
import torchvision 
import math
from numpy.linalg import norm
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4, 0.4822, 0.4465), (0.247, 0.243, 0.261))])
transform1 = transforms.Compose(
    [    
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, 4),
    transforms.ToTensor(),
    transforms.Normalize((0.4, 0.4822, 0.4465), (0.247, 0.243, 0.261)),   
    ])
trainset = torchvision.datasets.CIFAR10(root='./', train=True,download=True,transform = transform1)
validset = torchvision.datasets.CIFAR10(root='./', train=True,download=True, transform = transform) 
valid = list(range(40000, 50000,1))
validset1 = torch.utils.data.Subset(validset, valid)
validloader = torch.utils.data.DataLoader(validset1, shuffle=True, num_workers=4,batch_size = 100)
testset = torchvision.datasets.CIFAR10(root='./data', train = False, download=True, transform=transform)
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

from torch.autograd import Variable

__all__ = ['ResNet', 'resnet20', 'resnet32', 'resnet44', 'resnet56', 'resnet110', 'resnet1202']

def _weights_init(m):
    classname = m.__class__.__name__
    #print(classname)
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

class LambdaLayer(nn.Module):
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1, option='A'):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            if option == 'A':
                """
                For CIFAR10 ResNet paper uses option A.
                """
                self.shortcut = LambdaLayer(lambda x:
                                            F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4), "constant", 0))
            elif option == 'B':
                self.shortcut = nn.Sequential(
                     nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                     nn.BatchNorm2d(self.expansion * planes)
                )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)

        self.apply(_weights_init)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def resnet20():
    return ResNet(BasicBlock, [3, 3, 3])


def resnet32():
    return ResNet(BasicBlock, [5, 5, 5])


def resnet44():
    return ResNet(BasicBlock, [7, 7, 7])


def resnet56():
    return ResNet(BasicBlock, [9, 9, 9])


def resnet110():
    return ResNet(BasicBlock, [18, 18, 18])


def resnet1202():
    return ResNet(BasicBlock, [200, 200, 200])


def test(net):
    import numpy as np
    total_params = 0

    for x in filter(lambda p: p.requires_grad, net.parameters()):
        total_params += np.prod(x.data.numpy().shape)
    print("Total number of params", total_params)
    print("Total layers", len(list(filter(lambda p: p.requires_grad and len(p.data.size())>1, net.parameters()))))


if __name__ == "__main__":
    for net_name in __all__:
        if net_name.startswith('resnet'):
            print(net_name)
            test(globals()[net_name]())
            print()
# Out:
# resnet20
# Total number of params 269722
# Total layers 20
#
# resnet32
# Total number of params 464154
# Total layers 32
#
# resnet44
# Total number of params 658586
# Total layers 44
#
# resnet56
# Total number of params 853018
# Total layers 56
#
# resnet110
# Total number of params 1727962
# Total layers 110
#
# resnet1202
# Total number of params 19421274
# Total layers 1202

# %%
def get_n_params(model):
    pp=0
    for p in list(model.fc.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        pp += nn
    return pp

# %%
    """
    model = torchvision.models.vgg19(pretrained = True)
    model.classifier[5] = nn.Sequential(
                    nn.Dropout(p=0.5, inplace=False),
                    nn.Linear(4096, 512, bias = True), 
                    nn.ReLU(), 
                    nn.Dropout(0.6, inplace=False),
                    nn.Linear(512, 256, bias = True),
                    nn.ReLU(),
                    nn.Dropout(p=0.5, inplace=False))
    for parameter in model.parameters():
        parameter.requires_grad = False
    model.classifier[6] = nn.Sequential(
                    nn.Linear(256, 64, bias = True),
                    nn.ReLU(),
                    nn.Dropout(p=0.5, inplace=False),
                    nn.Linear(64, 10))
    """
    model = resnet20()
    model.load_state_dict(torch.load("/notebooks/resnet205k1"))
    
    model.to(device)  
    arr = np.array([])
    for name, param in model.named_parameters():
        temp = param.cpu().detach().numpy()
        bruh = temp.flatten()
        arr =np.concatenate((arr,bruh),axis = 0)
    arr =np.reshape(arr, (1,-1))

    print(arr.shape)
    print(np.linalg.norm(arr))
#model1 = generate_noise(model,tensor)
# Out:
# (1, 269722)
# 54.36494077938102

# %%
matrix = np.array([])
count = 1
avg = 0 
for i in range(10): 
    print("##########################################################")
    print("#########################################################")
    print("trial: " + str(i))
    indices = torch.randperm(len(trainset))[:15000]
    print(indices)
    trainset1 = torch.utils.data.Subset(trainset, indices)
    modelloader = torch.utils.data.DataLoader(trainset1, shuffle=True, num_workers=2, batch_size = 100)
    testloader = torch.utils.data.DataLoader(testset, shuffle=True, num_workers=2, batch_size = 20)
    #model pretrained by resnet
    #model = ResNet(ResidualBlock, [3, 4, 6, 3]).to(device)
    model = resnet20()
    model.load_state_dict(torch.load("/notebooks/resnet205k1"))
    model.to(device) 
    #print(get_n_params(model))
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01, weight_decay = 0.0001, momentum=0.9)
  ################
  #training model
  ####################
    train_losslist = []
    n_epochs = [*range(200)]
    valid_loss_min = np.Inf # track change in validation loss

    for epoch in n_epochs:
    # keep track of training and validation loss
        train_loss = 0.0
        train_loss1 = 0.0
        valid_loss = 0.0   
    ###################
    # train the model #
    ###################
        model.train()
    #model1.train()
        class_correct1 = list(0. for i in range(10))
        class_total1 = list(0. for i in range(10))
        for data, target in modelloader:
        # move tensors to GPU if CUDA is available
            data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
            optimizer.zero_grad()
        #optimizer1.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
        #output1 = model1(data)
        # calculate the batch loss
            loss = criterion(output, target)
        #loss1 = criterion1(output1,target)
        # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
        #loss1.backward()
        # perform a single optimization step (parameter update)
            optimizer.step()
        #exp_lr_scheduler.step()
        #optimizer1.step()
        # update training loss
            train_loss += loss.item()*data.size(0)
        #train_loss1 += loss1.item()*data.size(0)
            _, pred = torch.max(output, 1)    
        # compare predictions to true label
            correct_tensor = pred.eq(target.data.view_as(pred))
            correct = np.squeeze(correct_tensor.cpu().numpy())
        # calculate test accuracy for each object class
            for i in range(100):
                label = target.data[i]
                class_correct1[label] += correct[i].item()
                class_total1[label] += 1
    ######################    
    # validate the model #
    ######################
        model.eval()
        class_correct = list(0. for i in range(10))
        class_total = list(0. for i in range(10))
        for data, target in validloader:
            # move tensors to GPU if CUDA is available
            #if train_on_gpu:
            data, target = data.cuda(), target.cuda()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # update average validation loss 
            valid_loss += loss.item()*data.size(0)
            # convert output probabilities to predicted class
            _, pred = torch.max(output, 1)    
            # compare predictions to true label
            correct_tensor = pred.eq(target.data.view_as(pred))
            correct = np.squeeze(correct_tensor.cpu().numpy())
            # calculate test accuracy for each object class
            for i in range(100):
                label = target.data[i]
                class_correct[label] += correct[i].item()
                class_total[label] += 1
            # calculate average losses
        valid_loss = valid_loss/len(validloader.dataset)
        train_loss = train_loss/len(modelloader.dataset)
        train_losslist.append(train_loss)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
        print('Training Accuracy (Overall): %2d%% (%2d/%2d)' % (
        100. * np.sum(class_correct1) / np.sum(class_total1),
        np.sum(class_correct1), np.sum(class_total1)))
        print('Validation Accuracy (Overall): %2d%% (%2d/%2d)' % (
        100. * np.sum(class_correct) / np.sum(class_total),
        np.sum(class_correct), np.sum(class_total)))
    ########################
    # testing model #
    ######################### 
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    test_loss = 0.
    train_on_gpu = torch.cuda.is_available()
    model.eval()
    # iterate over test data
    for data, target in testloader:
        # move tensors to GPU if CUDA is available
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update test loss 
        test_loss += loss.item()*data.size(0)
        # convert output probabilities to predicted class
        _, pred = torch.max(output, 1)    
        # compare predictions to true label
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
        # calculate test accuracy for each object class
        for i in range(20):
            label = target.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1
    # average test loss
    test_loss = test_loss/len(modelloader.dataset)
    print('Test Loss: {:.6f}\n'.format(test_loss))

    for i in range(10):
        if class_total[i] > 0:
            print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
              classes[i], 100 * class_correct[i] / class_total[i],
              np.sum(class_correct[i]), np.sum(class_total[i])))
        else:
            print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
    print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
    avg += (100. * np.sum(class_correct) / np.sum(class_total))
    arr = np.array([])
    for name, param in model.named_parameters():
        temp = param.cpu().detach().numpy()
        bruh = temp.flatten()
        arr =np.concatenate((arr,bruh),axis = 0)
    arr =np.reshape(arr, (1,-1))

    print(arr.shape)
    if matrix.size == 0:
        matrix = arr
    else: 
        matrix = np.append(matrix, arr, axis = 0)
    print(count)
    torch.save(model.state_dict(), "test"+str(count))
    count = count +1
print(avg/10)
# Out:
# ##########################################################
# #########################################################
# trial: 0
# tensor([11988,  2723, 11734,  ...,  9692, 49928, 19740])
# Epoch: 0 	Training Loss: 1.034979 	Validation Loss: 0.821066
# Training Accuracy (Overall): 72% (10801/15000)
# Validation Accuracy (Overall): 75% (7565/10000)
# Epoch: 1 	Training Loss: 0.670179 	Validation Loss: 0.637612
# Training Accuracy (Overall): 77% (11661/15000)
# Validation Accuracy (Overall): 79% (7978/10000)
# Epoch: 2 	Training Loss: 0.594116 	Validation Loss: 0.591658
# Training Accuracy (Overall): 79% (11937/15000)
# Validation Accuracy (Overall): 80% (8093/10000)
# Epoch: 3 	Training Loss: 0.570840 	Validation Loss: 0.587064
# Training Accuracy (Overall): 80% (12081/15000)
# Validation Accuracy (Overall): 80% (8090/10000)
# Epoch: 4 	Training Loss: 0.544822 	Validation Loss: 0.585103
# Training Accuracy (Overall): 81% (12201/15000)
# Validation Accuracy (Overall): 80% (8095/10000)
# Epoch: 5 	Training Loss: 0.522377 	Validation Loss: 0.585379
# Training Accuracy (Overall): 82% (12324/15000)
# Validation Accuracy (Overall): 80% (8098/10000)
# Epoch: 6 	Training Loss: 0.505647 	Validation Loss: 0.554466
# Training Accuracy (Overall): 83% (12463/15000)
# Validation Accuracy (Overall): 81% (8176/10000)
# Epoch: 7 	Training Loss: 0.488762 	Validation Loss: 0.544710
# Training Accuracy (Overall): 83% (12467/15000)
# Validation Accuracy (Overall): 81% (8184/10000)
# Epoch: 8 	Training Loss: 0.472527 	Validation Loss: 0.516933
# Training Accuracy (Overall): 83% (12560/15000)
# Validation Accuracy (Overall): 82% (8273/10000)
# Epoch: 9 	Training Loss: 0.465286 	Validation Loss: 0.530728
# Training Accuracy (Overall): 84% (12641/15000)
# Validation Accuracy (Overall): 82% (8230/10000)
# Epoch: 10 	Training Loss: 0.444897 	Validation Loss: 0.545584
# Training Accuracy (Overall): 84% (12716/15000)
# Validation Accuracy (Overall): 82% (8241/10000)
# Epoch: 11 	Training Loss: 0.433513 	Validation Loss: 0.558137
# Training Accuracy (Overall): 85% (12762/15000)
# Validation Accuracy (Overall): 81% (8189/10000)
# Epoch: 12 	Training Loss: 0.424406 	Validation Loss: 0.559478
# Training Accuracy (Overall): 85% (12819/15000)
# Validation Accuracy (Overall): 81% (8155/10000)
# Epoch: 13 	Training Loss: 0.418033 	Validation Loss: 0.527154
# Training Accuracy (Overall): 85% (12864/15000)
# Validation Accuracy (Overall): 82% (8272/10000)
# Epoch: 14 	Training Loss: 0.404884 	Validation Loss: 0.578938
# Training Accuracy (Overall): 86% (12901/15000)
# Validation Accuracy (Overall): 81% (8154/10000)
# Epoch: 15 	Training Loss: 0.400501 	Validation Loss: 0.540312
# Training Accuracy (Overall): 86% (12918/15000)
# Validation Accuracy (Overall): 82% (8245/10000)
# Epoch: 16 	Training Loss: 0.383097 	Validation Loss: 0.527632
# Training Accuracy (Overall): 86% (12982/15000)
# Validation Accuracy (Overall): 83% (8331/10000)
# Epoch: 17 	Training Loss: 0.379866 	Validation Loss: 0.523248
# Training Accuracy (Overall): 87% (13077/15000)
# Validation Accuracy (Overall): 83% (8338/10000)
# Epoch: 18 	Training Loss: 0.362799 	Validation Loss: 0.523081
# Training Accuracy (Overall): 87% (13079/15000)
# Validation Accuracy (Overall): 83% (8360/10000)
# Epoch: 19 	Training Loss: 0.354149 	Validation Loss: 0.530313
# Training Accuracy (Overall): 87% (13169/15000)
# Validation Accuracy (Overall): 83% (8331/10000)
# Epoch: 20 	Training Loss: 0.359332 	Validation Loss: 0.536565
# Training Accuracy (Overall): 87% (13140/15000)
# Validation Accuracy (Overall): 83% (8301/10000)
# Epoch: 21 	Training Loss: 0.342698 	Validation Loss: 0.519537
# Training Accuracy (Overall): 88% (13231/15000)
# Validation Accuracy (Overall): 83% (8364/10000)
# Epoch: 22 	Training Loss: 0.342183 	Validation Loss: 0.546266
# Training Accuracy (Overall): 88% (13235/15000)
# Validation Accuracy (Overall): 83% (8316/10000)
# Epoch: 23 	Training Loss: 0.329201 	Validation Loss: 0.558383
# Training Accuracy (Overall): 88% (13303/15000)
# Validation Accuracy (Overall): 82% (8258/10000)
# Epoch: 24 	Training Loss: 0.317873 	Validation Loss: 0.511877
# Training Accuracy (Overall): 88% (13347/15000)
# Validation Accuracy (Overall): 84% (8421/10000)
# Epoch: 25 	Training Loss: 0.307863 	Validation Loss: 0.558792
# Training Accuracy (Overall): 89% (13390/15000)
# Validation Accuracy (Overall): 82% (8295/10000)
# Epoch: 26 	Training Loss: 0.314830 	Validation Loss: 0.523086
# Training Accuracy (Overall): 89% (13351/15000)
# Validation Accuracy (Overall): 83% (8362/10000)
# Epoch: 27 	Training Loss: 0.297248 	Validation Loss: 0.533037
# Training Accuracy (Overall): 89% (13444/15000)
# Validation Accuracy (Overall): 83% (8388/10000)
# Epoch: 28 	Training Loss: 0.285723 	Validation Loss: 0.559133
# Training Accuracy (Overall): 90% (13524/15000)
# Validation Accuracy (Overall): 83% (8325/10000)
# Epoch: 29 	Training Loss: 0.288935 	Validation Loss: 0.566493
# Training Accuracy (Overall): 89% (13439/15000)
# Validation Accuracy (Overall): 83% (8319/10000)
# Epoch: 30 	Training Loss: 0.282798 	Validation Loss: 0.545018
# Training Accuracy (Overall): 90% (13528/15000)
# Validation Accuracy (Overall): 83% (8347/10000)
# Epoch: 31 	Training Loss: 0.265621 	Validation Loss: 0.533370
# Training Accuracy (Overall): 90% (13594/15000)
# Validation Accuracy (Overall): 84% (8422/10000)
# Epoch: 32 	Training Loss: 0.265285 	Validation Loss: 0.529508
# Training Accuracy (Overall): 90% (13604/15000)
# Validation Accuracy (Overall): 84% (8454/10000)
# Epoch: 33 	Training Loss: 0.269695 	Validation Loss: 0.547089
# Training Accuracy (Overall): 90% (13611/15000)
# Validation Accuracy (Overall): 83% (8395/10000)
# Epoch: 34 	Training Loss: 0.259390 	Validation Loss: 0.536428
# Training Accuracy (Overall): 91% (13664/15000)
# Validation Accuracy (Overall): 84% (8425/10000)
# Epoch: 35 	Training Loss: 0.253987 	Validation Loss: 0.552177
# Training Accuracy (Overall): 91% (13673/15000)
# Validation Accuracy (Overall): 84% (8414/10000)
# Epoch: 36 	Training Loss: 0.240555 	Validation Loss: 0.584452
# Training Accuracy (Overall): 91% (13755/15000)
# Validation Accuracy (Overall): 83% (8394/10000)
# Epoch: 37 	Training Loss: 0.238260 	Validation Loss: 0.524569
# Training Accuracy (Overall): 91% (13761/15000)
# Validation Accuracy (Overall): 84% (8443/10000)
# Epoch: 38 	Training Loss: 0.233823 	Validation Loss: 0.536075
# Training Accuracy (Overall): 91% (13760/15000)
# Validation Accuracy (Overall): 84% (8431/10000)
# Epoch: 39 	Training Loss: 0.229672 	Validation Loss: 0.548427
# Training Accuracy (Overall): 91% (13793/15000)
# Validation Accuracy (Overall): 84% (8456/10000)
# Epoch: 40 	Training Loss: 0.227139 	Validation Loss: 0.570676
# Training Accuracy (Overall): 91% (13798/15000)
# Validation Accuracy (Overall): 84% (8408/10000)
# Epoch: 41 	Training Loss: 0.222036 	Validation Loss: 0.561128
# Training Accuracy (Overall): 92% (13804/15000)
# Validation Accuracy (Overall): 84% (8472/10000)
# Epoch: 42 	Training Loss: 0.215929 	Validation Loss: 0.578683
# Training Accuracy (Overall): 92% (13833/15000)
# Validation Accuracy (Overall): 83% (8373/10000)
# Epoch: 43 	Training Loss: 0.208161 	Validation Loss: 0.540724
# Training Accuracy (Overall): 92% (13881/15000)
# Validation Accuracy (Overall): 85% (8514/10000)
# Epoch: 44 	Training Loss: 0.213403 	Validation Loss: 0.577682
# Training Accuracy (Overall): 92% (13871/15000)
# Validation Accuracy (Overall): 84% (8435/10000)
# Epoch: 45 	Training Loss: 0.204380 	Validation Loss: 0.534638
# Training Accuracy (Overall): 92% (13892/15000)
# Validation Accuracy (Overall): 84% (8495/10000)
# Epoch: 46 	Training Loss: 0.209316 	Validation Loss: 0.625075
# Training Accuracy (Overall): 92% (13875/15000)
# Validation Accuracy (Overall): 83% (8379/10000)
# Epoch: 47 	Training Loss: 0.197140 	Validation Loss: 0.516766
# Training Accuracy (Overall): 92% (13949/15000)
# Validation Accuracy (Overall): 85% (8564/10000)
# Epoch: 48 	Training Loss: 0.198319 	Validation Loss: 0.554823
# Training Accuracy (Overall): 93% (13950/15000)
# Validation Accuracy (Overall): 84% (8463/10000)
# Epoch: 49 	Training Loss: 0.186237 	Validation Loss: 0.602361
# Training Accuracy (Overall): 93% (14002/15000)
# Validation Accuracy (Overall): 83% (8360/10000)
# Epoch: 50 	Training Loss: 0.187167 	Validation Loss: 0.649095
# Training Accuracy (Overall): 93% (14036/15000)
# Validation Accuracy (Overall): 83% (8323/10000)
# Epoch: 51 	Training Loss: 0.180838 	Validation Loss: 0.550427
# Training Accuracy (Overall): 93% (14023/15000)
# Validation Accuracy (Overall): 85% (8535/10000)
# Epoch: 52 	Training Loss: 0.178055 	Validation Loss: 0.641313
# Training Accuracy (Overall): 93% (14057/15000)
# Validation Accuracy (Overall): 83% (8346/10000)
# Epoch: 53 	Training Loss: 0.176759 	Validation Loss: 0.607485
# Training Accuracy (Overall): 93% (14068/15000)
# Validation Accuracy (Overall): 84% (8434/10000)
# Epoch: 54 	Training Loss: 0.169117 	Validation Loss: 0.518410
# Training Accuracy (Overall): 94% (14101/15000)
# Validation Accuracy (Overall): 86% (8612/10000)
# Epoch: 55 	Training Loss: 0.172029 	Validation Loss: 0.556314
# Training Accuracy (Overall): 93% (14085/15000)
# Validation Accuracy (Overall): 84% (8488/10000)
# Epoch: 56 	Training Loss: 0.173828 	Validation Loss: 0.582545
# Training Accuracy (Overall): 93% (14064/15000)
# Validation Accuracy (Overall): 85% (8505/10000)
# Epoch: 57 	Training Loss: 0.168142 	Validation Loss: 0.583814
# Training Accuracy (Overall): 93% (14084/15000)
# Validation Accuracy (Overall): 85% (8522/10000)
# Epoch: 58 	Training Loss: 0.168802 	Validation Loss: 0.524729
# Training Accuracy (Overall): 93% (14072/15000)
# Validation Accuracy (Overall): 86% (8655/10000)
# Epoch: 59 	Training Loss: 0.158671 	Validation Loss: 0.582753
# Training Accuracy (Overall): 94% (14190/15000)
# Validation Accuracy (Overall): 85% (8548/10000)
# Epoch: 60 	Training Loss: 0.146291 	Validation Loss: 0.595204
# Training Accuracy (Overall): 94% (14243/15000)
# Validation Accuracy (Overall): 85% (8514/10000)
# Epoch: 61 	Training Loss: 0.153105 	Validation Loss: 0.565175
# Training Accuracy (Overall): 94% (14191/15000)
# Validation Accuracy (Overall): 85% (8583/10000)
# Epoch: 62 	Training Loss: 0.154451 	Validation Loss: 0.550211
# Training Accuracy (Overall): 94% (14165/15000)
# Validation Accuracy (Overall): 86% (8611/10000)
# Epoch: 63 	Training Loss: 0.154513 	Validation Loss: 0.602417
# Training Accuracy (Overall): 94% (14175/15000)
# Validation Accuracy (Overall): 85% (8532/10000)
# Epoch: 64 	Training Loss: 0.145764 	Validation Loss: 0.630758
# Training Accuracy (Overall): 94% (14236/15000)
# Validation Accuracy (Overall): 85% (8511/10000)
# Epoch: 65 	Training Loss: 0.141081 	Validation Loss: 0.581525
# Training Accuracy (Overall): 95% (14272/15000)
# Validation Accuracy (Overall): 85% (8569/10000)
# Epoch: 66 	Training Loss: 0.136496 	Validation Loss: 0.621983
# Training Accuracy (Overall): 95% (14285/15000)
# Validation Accuracy (Overall): 85% (8547/10000)
# Epoch: 67 	Training Loss: 0.145211 	Validation Loss: 0.571444
# Training Accuracy (Overall): 94% (14239/15000)
# Validation Accuracy (Overall): 86% (8616/10000)
# Epoch: 68 	Training Loss: 0.135113 	Validation Loss: 0.588737
# Training Accuracy (Overall): 95% (14293/15000)
# Validation Accuracy (Overall): 85% (8569/10000)
# Epoch: 69 	Training Loss: 0.136995 	Validation Loss: 0.580868
# Training Accuracy (Overall): 95% (14278/15000)
# Validation Accuracy (Overall): 86% (8606/10000)
# Epoch: 70 	Training Loss: 0.130957 	Validation Loss: 0.586569
# Training Accuracy (Overall): 95% (14313/15000)
# Validation Accuracy (Overall): 86% (8623/10000)
# Epoch: 71 	Training Loss: 0.128273 	Validation Loss: 0.590726
# Training Accuracy (Overall): 95% (14319/15000)
# Validation Accuracy (Overall): 85% (8564/10000)
# Epoch: 72 	Training Loss: 0.126688 	Validation Loss: 0.613674
# Training Accuracy (Overall): 95% (14302/15000)
# Validation Accuracy (Overall): 85% (8550/10000)
# Epoch: 73 	Training Loss: 0.127455 	Validation Loss: 0.603147
# Training Accuracy (Overall): 95% (14344/15000)
# Validation Accuracy (Overall): 85% (8571/10000)
# Epoch: 74 	Training Loss: 0.120294 	Validation Loss: 0.603566
# Training Accuracy (Overall): 95% (14355/15000)
# Validation Accuracy (Overall): 85% (8557/10000)
# Epoch: 75 	Training Loss: 0.110672 	Validation Loss: 0.620590
# Training Accuracy (Overall): 96% (14427/15000)
# Validation Accuracy (Overall): 85% (8542/10000)
# Epoch: 76 	Training Loss: 0.119060 	Validation Loss: 0.597739
# Training Accuracy (Overall): 95% (14382/15000)
# Validation Accuracy (Overall): 86% (8617/10000)
# Epoch: 77 	Training Loss: 0.120678 	Validation Loss: 0.582430
# Training Accuracy (Overall): 95% (14341/15000)
# Validation Accuracy (Overall): 86% (8601/10000)
# Epoch: 78 	Training Loss: 0.123867 	Validation Loss: 0.629965
# Training Accuracy (Overall): 95% (14343/15000)
# Validation Accuracy (Overall): 85% (8570/10000)
# Epoch: 79 	Training Loss: 0.121135 	Validation Loss: 0.604669
# Training Accuracy (Overall): 95% (14341/15000)
# Validation Accuracy (Overall): 86% (8628/10000)
# Epoch: 80 	Training Loss: 0.113469 	Validation Loss: 0.569224
# Training Accuracy (Overall): 95% (14395/15000)
# Validation Accuracy (Overall): 86% (8638/10000)
# Epoch: 81 	Training Loss: 0.116568 	Validation Loss: 0.570007
# Training Accuracy (Overall): 95% (14394/15000)
# Validation Accuracy (Overall): 86% (8698/10000)
# Epoch: 82 	Training Loss: 0.106988 	Validation Loss: 0.607397
# Training Accuracy (Overall): 96% (14440/15000)
# Validation Accuracy (Overall): 85% (8586/10000)
# Epoch: 83 	Training Loss: 0.100688 	Validation Loss: 0.747819
# Training Accuracy (Overall): 96% (14479/15000)
# Validation Accuracy (Overall): 83% (8388/10000)
# Epoch: 84 	Training Loss: 0.101915 	Validation Loss: 0.624957
# Training Accuracy (Overall): 96% (14465/15000)
# Validation Accuracy (Overall): 86% (8617/10000)
# Epoch: 85 	Training Loss: 0.104101 	Validation Loss: 0.633889
# Training Accuracy (Overall): 96% (14462/15000)
# Validation Accuracy (Overall): 86% (8605/10000)
# Epoch: 86 	Training Loss: 0.112625 	Validation Loss: 0.638766
# Training Accuracy (Overall): 96% (14401/15000)
# Validation Accuracy (Overall): 86% (8600/10000)
# Epoch: 87 	Training Loss: 0.099382 	Validation Loss: 0.616076
# Training Accuracy (Overall): 96% (14460/15000)
# Validation Accuracy (Overall): 86% (8643/10000)
# Epoch: 88 	Training Loss: 0.098795 	Validation Loss: 0.697810
# Training Accuracy (Overall): 96% (14479/15000)
# Validation Accuracy (Overall): 85% (8549/10000)
# Epoch: 89 	Training Loss: 0.100386 	Validation Loss: 0.631255
# Training Accuracy (Overall): 96% (14470/15000)
# Validation Accuracy (Overall): 85% (8567/10000)
# Epoch: 90 	Training Loss: 0.102650 	Validation Loss: 0.677896
# Training Accuracy (Overall): 96% (14445/15000)
# Validation Accuracy (Overall): 85% (8507/10000)
# Epoch: 91 	Training Loss: 0.099734 	Validation Loss: 0.619577
# Training Accuracy (Overall): 96% (14467/15000)
# Validation Accuracy (Overall): 86% (8661/10000)
# Epoch: 92 	Training Loss: 0.091233 	Validation Loss: 0.646373
# Training Accuracy (Overall): 96% (14500/15000)
# Validation Accuracy (Overall): 85% (8591/10000)
# Epoch: 93 	Training Loss: 0.092836 	Validation Loss: 0.576351
# Training Accuracy (Overall): 96% (14522/15000)
# Validation Accuracy (Overall): 87% (8726/10000)
# Epoch: 94 	Training Loss: 0.097941 	Validation Loss: 0.608130
# Training Accuracy (Overall): 96% (14484/15000)
# Validation Accuracy (Overall): 86% (8638/10000)
# Epoch: 95 	Training Loss: 0.101167 	Validation Loss: 0.653513
# Training Accuracy (Overall): 96% (14464/15000)
# Validation Accuracy (Overall): 86% (8624/10000)
# Epoch: 96 	Training Loss: 0.094587 	Validation Loss: 0.620573
# Training Accuracy (Overall): 96% (14497/15000)
# Validation Accuracy (Overall): 86% (8676/10000)
# Epoch: 97 	Training Loss: 0.088918 	Validation Loss: 0.656730
# Training Accuracy (Overall): 96% (14508/15000)
# Validation Accuracy (Overall): 85% (8526/10000)
# Epoch: 98 	Training Loss: 0.093238 	Validation Loss: 0.645754
# Training Accuracy (Overall): 96% (14510/15000)
# Validation Accuracy (Overall): 86% (8601/10000)
# Epoch: 99 	Training Loss: 0.086188 	Validation Loss: 0.619868
# Training Accuracy (Overall): 96% (14545/15000)
# Validation Accuracy (Overall): 86% (8687/10000)
# Epoch: 100 	Training Loss: 0.092578 	Validation Loss: 0.581725
# Training Accuracy (Overall): 96% (14497/15000)
# Validation Accuracy (Overall): 86% (8687/10000)
# Epoch: 101 	Training Loss: 0.085160 	Validation Loss: 0.601622
# Training Accuracy (Overall): 97% (14567/15000)
# Validation Accuracy (Overall): 86% (8682/10000)
# Epoch: 102 	Training Loss: 0.082071 	Validation Loss: 0.613154
# Training Accuracy (Overall): 97% (14574/15000)
# Validation Accuracy (Overall): 86% (8687/10000)
# Epoch: 103 	Training Loss: 0.075818 	Validation Loss: 0.609147
# Training Accuracy (Overall): 97% (14617/15000)
# Validation Accuracy (Overall): 87% (8710/10000)
# Epoch: 104 	Training Loss: 0.072890 	Validation Loss: 0.620059
# Training Accuracy (Overall): 97% (14625/15000)
# Validation Accuracy (Overall): 86% (8639/10000)
# Epoch: 105 	Training Loss: 0.081706 	Validation Loss: 0.625665
# Training Accuracy (Overall): 97% (14587/15000)
# Validation Accuracy (Overall): 87% (8700/10000)
# Epoch: 106 	Training Loss: 0.087924 	Validation Loss: 0.682500
# Training Accuracy (Overall): 96% (14531/15000)
# Validation Accuracy (Overall): 86% (8634/10000)
# Epoch: 107 	Training Loss: 0.086985 	Validation Loss: 0.625446
# Training Accuracy (Overall): 97% (14560/15000)
# Validation Accuracy (Overall): 86% (8652/10000)
# Epoch: 108 	Training Loss: 0.086615 	Validation Loss: 0.623015
# Training Accuracy (Overall): 97% (14561/15000)
# Validation Accuracy (Overall): 86% (8649/10000)
# Epoch: 109 	Training Loss: 0.079213 	Validation Loss: 0.613975
# Training Accuracy (Overall): 97% (14589/15000)
# Validation Accuracy (Overall): 86% (8665/10000)
# Epoch: 110 	Training Loss: 0.078197 	Validation Loss: 0.683709
# Training Accuracy (Overall): 97% (14588/15000)
# Validation Accuracy (Overall): 86% (8621/10000)
# Epoch: 111 	Training Loss: 0.084794 	Validation Loss: 0.639409
# Training Accuracy (Overall): 97% (14550/15000)
# Validation Accuracy (Overall): 86% (8649/10000)
# Epoch: 112 	Training Loss: 0.081444 	Validation Loss: 0.640267
# Training Accuracy (Overall): 97% (14568/15000)
# Validation Accuracy (Overall): 86% (8676/10000)
# Epoch: 113 	Training Loss: 0.072489 	Validation Loss: 0.639282
# Training Accuracy (Overall): 97% (14616/15000)
# Validation Accuracy (Overall): 86% (8637/10000)
# Epoch: 114 	Training Loss: 0.071526 	Validation Loss: 0.633416
# Training Accuracy (Overall): 97% (14624/15000)
# Validation Accuracy (Overall): 87% (8736/10000)
# Epoch: 115 	Training Loss: 0.077624 	Validation Loss: 0.720596
# Training Accuracy (Overall): 97% (14596/15000)
# Validation Accuracy (Overall): 85% (8563/10000)
# Epoch: 116 	Training Loss: 0.072023 	Validation Loss: 0.646626
# Training Accuracy (Overall): 97% (14611/15000)
# Validation Accuracy (Overall): 86% (8668/10000)
# Epoch: 117 	Training Loss: 0.075019 	Validation Loss: 0.613558
# Training Accuracy (Overall): 97% (14608/15000)
# Validation Accuracy (Overall): 87% (8716/10000)
# Epoch: 118 	Training Loss: 0.071783 	Validation Loss: 0.634086
# Training Accuracy (Overall): 97% (14624/15000)
# Validation Accuracy (Overall): 86% (8645/10000)
# Epoch: 119 	Training Loss: 0.073703 	Validation Loss: 0.690152
# Training Accuracy (Overall): 97% (14625/15000)
# Validation Accuracy (Overall): 85% (8575/10000)
# Epoch: 120 	Training Loss: 0.075828 	Validation Loss: 0.670456
# Training Accuracy (Overall): 97% (14619/15000)
# Validation Accuracy (Overall): 86% (8638/10000)
# Epoch: 121 	Training Loss: 0.073250 	Validation Loss: 0.669438
# Training Accuracy (Overall): 97% (14617/15000)
# Validation Accuracy (Overall): 86% (8641/10000)
# Epoch: 122 	Training Loss: 0.066701 	Validation Loss: 0.666334
# Training Accuracy (Overall): 97% (14647/15000)
# Validation Accuracy (Overall): 86% (8677/10000)
# Epoch: 123 	Training Loss: 0.062492 	Validation Loss: 0.628635
# Training Accuracy (Overall): 97% (14685/15000)
# Validation Accuracy (Overall): 87% (8738/10000)
# Epoch: 124 	Training Loss: 0.067235 	Validation Loss: 0.659490
# Training Accuracy (Overall): 97% (14649/15000)
# Validation Accuracy (Overall): 86% (8684/10000)
# Epoch: 125 	Training Loss: 0.066655 	Validation Loss: 0.622550
# Training Accuracy (Overall): 97% (14643/15000)
# Validation Accuracy (Overall): 87% (8728/10000)
# Epoch: 126 	Training Loss: 0.070675 	Validation Loss: 0.656118
# Training Accuracy (Overall): 97% (14619/15000)
# Validation Accuracy (Overall): 86% (8688/10000)
# Epoch: 127 	Training Loss: 0.062701 	Validation Loss: 0.627913
# Training Accuracy (Overall): 97% (14651/15000)
# Validation Accuracy (Overall): 87% (8722/10000)
# Epoch: 128 	Training Loss: 0.065922 	Validation Loss: 0.659685
# Training Accuracy (Overall): 97% (14671/15000)
# Validation Accuracy (Overall): 87% (8713/10000)
# Epoch: 129 	Training Loss: 0.061008 	Validation Loss: 0.643824
# Training Accuracy (Overall): 97% (14671/15000)
# Validation Accuracy (Overall): 87% (8724/10000)
# Epoch: 130 	Training Loss: 0.061150 	Validation Loss: 0.608096
# Training Accuracy (Overall): 97% (14697/15000)
# Validation Accuracy (Overall): 87% (8760/10000)
# Epoch: 131 	Training Loss: 0.059815 	Validation Loss: 0.668093
# Training Accuracy (Overall): 97% (14679/15000)
# Validation Accuracy (Overall): 86% (8697/10000)
# Epoch: 132 	Training Loss: 0.062414 	Validation Loss: 0.701838
# Training Accuracy (Overall): 97% (14695/15000)
# Validation Accuracy (Overall): 86% (8646/10000)
# Epoch: 133 	Training Loss: 0.063770 	Validation Loss: 0.674323
# Training Accuracy (Overall): 97% (14674/15000)
# Validation Accuracy (Overall): 86% (8607/10000)
# Epoch: 134 	Training Loss: 0.057800 	Validation Loss: 0.626510
# Training Accuracy (Overall): 98% (14726/15000)
# Validation Accuracy (Overall): 87% (8716/10000)
# Epoch: 135 	Training Loss: 0.064379 	Validation Loss: 0.650415
# Training Accuracy (Overall): 97% (14682/15000)
# Validation Accuracy (Overall): 87% (8732/10000)
# Epoch: 136 	Training Loss: 0.062012 	Validation Loss: 0.618771
# Training Accuracy (Overall): 98% (14709/15000)
# Validation Accuracy (Overall): 87% (8754/10000)
# Epoch: 137 	Training Loss: 0.057802 	Validation Loss: 0.810943
# Training Accuracy (Overall): 98% (14703/15000)
# Validation Accuracy (Overall): 84% (8452/10000)
# Epoch: 138 	Training Loss: 0.052477 	Validation Loss: 0.634211
# Training Accuracy (Overall): 98% (14720/15000)
# Validation Accuracy (Overall): 87% (8722/10000)
# Epoch: 139 	Training Loss: 0.056591 	Validation Loss: 0.641148
# Training Accuracy (Overall): 98% (14707/15000)
# Validation Accuracy (Overall): 87% (8738/10000)
# Epoch: 140 	Training Loss: 0.058862 	Validation Loss: 0.660629
# Training Accuracy (Overall): 98% (14705/15000)
# Validation Accuracy (Overall): 86% (8675/10000)
# Epoch: 141 	Training Loss: 0.058010 	Validation Loss: 0.661913
# Training Accuracy (Overall): 97% (14696/15000)
# Validation Accuracy (Overall): 87% (8717/10000)
# Epoch: 142 	Training Loss: 0.053638 	Validation Loss: 0.680956
# Training Accuracy (Overall): 98% (14727/15000)
# Validation Accuracy (Overall): 87% (8714/10000)
# Epoch: 143 	Training Loss: 0.051901 	Validation Loss: 0.660485
# Training Accuracy (Overall): 98% (14728/15000)
# Validation Accuracy (Overall): 87% (8718/10000)
# Epoch: 144 	Training Loss: 0.052723 	Validation Loss: 0.696547
# Training Accuracy (Overall): 98% (14731/15000)
# Validation Accuracy (Overall): 86% (8690/10000)
# Epoch: 145 	Training Loss: 0.057831 	Validation Loss: 0.684801
# Training Accuracy (Overall): 97% (14698/15000)
# Validation Accuracy (Overall): 87% (8708/10000)
# Epoch: 146 	Training Loss: 0.061767 	Validation Loss: 0.754799
# Training Accuracy (Overall): 97% (14681/15000)
# Validation Accuracy (Overall): 85% (8587/10000)
# Epoch: 147 	Training Loss: 0.058443 	Validation Loss: 0.684181
# Training Accuracy (Overall): 98% (14710/15000)
# Validation Accuracy (Overall): 86% (8694/10000)
# Epoch: 148 	Training Loss: 0.068566 	Validation Loss: 0.673867
# Training Accuracy (Overall): 97% (14644/15000)
# Validation Accuracy (Overall): 87% (8707/10000)
# Epoch: 149 	Training Loss: 0.064152 	Validation Loss: 0.673142
# Training Accuracy (Overall): 97% (14656/15000)
# Validation Accuracy (Overall): 87% (8759/10000)
# Epoch: 150 	Training Loss: 0.060883 	Validation Loss: 0.644023
# Training Accuracy (Overall): 97% (14694/15000)
# Validation Accuracy (Overall): 87% (8782/10000)
# Epoch: 151 	Training Loss: 0.060170 	Validation Loss: 0.651390
# Training Accuracy (Overall): 97% (14690/15000)
# Validation Accuracy (Overall): 87% (8749/10000)
# Epoch: 152 	Training Loss: 0.053381 	Validation Loss: 0.700010
# Training Accuracy (Overall): 98% (14718/15000)
# Validation Accuracy (Overall): 87% (8709/10000)
# Epoch: 153 	Training Loss: 0.058241 	Validation Loss: 0.699621
# Training Accuracy (Overall): 98% (14706/15000)
# Validation Accuracy (Overall): 86% (8638/10000)
# Epoch: 154 	Training Loss: 0.058473 	Validation Loss: 0.658266
# Training Accuracy (Overall): 97% (14698/15000)
# Validation Accuracy (Overall): 87% (8701/10000)
# Epoch: 155 	Training Loss: 0.046677 	Validation Loss: 0.654071
# Training Accuracy (Overall): 98% (14754/15000)
# Validation Accuracy (Overall): 87% (8745/10000)
# Epoch: 156 	Training Loss: 0.045055 	Validation Loss: 0.657968
# Training Accuracy (Overall): 98% (14774/15000)
# Validation Accuracy (Overall): 87% (8731/10000)
# Epoch: 157 	Training Loss: 0.056791 	Validation Loss: 0.675475
# Training Accuracy (Overall): 98% (14715/15000)
# Validation Accuracy (Overall): 86% (8690/10000)
# Epoch: 158 	Training Loss: 0.052823 	Validation Loss: 0.711187
# Training Accuracy (Overall): 98% (14729/15000)
# Validation Accuracy (Overall): 86% (8699/10000)
# Epoch: 159 	Training Loss: 0.058630 	Validation Loss: 0.707905
# Training Accuracy (Overall): 97% (14697/15000)
# Validation Accuracy (Overall): 86% (8683/10000)
# Epoch: 160 	Training Loss: 0.051574 	Validation Loss: 0.719623
# Training Accuracy (Overall): 98% (14740/15000)
# Validation Accuracy (Overall): 86% (8657/10000)
# Epoch: 161 	Training Loss: 0.055648 	Validation Loss: 0.738880
# Training Accuracy (Overall): 98% (14710/15000)
# Validation Accuracy (Overall): 86% (8655/10000)
# Epoch: 162 	Training Loss: 0.047680 	Validation Loss: 0.625126
# Training Accuracy (Overall): 98% (14760/15000)
# Validation Accuracy (Overall): 87% (8795/10000)
# Epoch: 163 	Training Loss: 0.041471 	Validation Loss: 0.694189
# Training Accuracy (Overall): 98% (14785/15000)
# Validation Accuracy (Overall): 87% (8730/10000)
# Epoch: 164 	Training Loss: 0.049356 	Validation Loss: 0.678356
# Training Accuracy (Overall): 98% (14741/15000)
# Validation Accuracy (Overall): 87% (8747/10000)
# Epoch: 165 	Training Loss: 0.047447 	Validation Loss: 0.662344
# Training Accuracy (Overall): 98% (14764/15000)
# Validation Accuracy (Overall): 87% (8734/10000)
# Epoch: 166 	Training Loss: 0.055694 	Validation Loss: 0.651900
# Training Accuracy (Overall): 98% (14725/15000)
# Validation Accuracy (Overall): 87% (8747/10000)
# Epoch: 167 	Training Loss: 0.051543 	Validation Loss: 0.682861
# Training Accuracy (Overall): 98% (14735/15000)
# Validation Accuracy (Overall): 87% (8741/10000)
# Epoch: 168 	Training Loss: 0.048353 	Validation Loss: 0.717908
# Training Accuracy (Overall): 98% (14759/15000)
# Validation Accuracy (Overall): 86% (8639/10000)
# Epoch: 169 	Training Loss: 0.049336 	Validation Loss: 0.659990
# Training Accuracy (Overall): 98% (14750/15000)
# Validation Accuracy (Overall): 87% (8764/10000)
# Epoch: 170 	Training Loss: 0.044762 	Validation Loss: 0.689182
# Training Accuracy (Overall): 98% (14785/15000)
# Validation Accuracy (Overall): 87% (8727/10000)
# Epoch: 171 	Training Loss: 0.039721 	Validation Loss: 0.610508
# Training Accuracy (Overall): 98% (14794/15000)
# Validation Accuracy (Overall): 87% (8794/10000)
# Epoch: 172 	Training Loss: 0.049042 	Validation Loss: 0.736039
# Training Accuracy (Overall): 98% (14745/15000)
# Validation Accuracy (Overall): 86% (8693/10000)
# Epoch: 173 	Training Loss: 0.053973 	Validation Loss: 0.697480
# Training Accuracy (Overall): 98% (14724/15000)
# Validation Accuracy (Overall): 87% (8711/10000)
# Epoch: 174 	Training Loss: 0.053268 	Validation Loss: 0.638245
# Training Accuracy (Overall): 98% (14705/15000)
# Validation Accuracy (Overall): 87% (8755/10000)
# Epoch: 175 	Training Loss: 0.055269 	Validation Loss: 0.722794
# Training Accuracy (Overall): 98% (14711/15000)
# Validation Accuracy (Overall): 86% (8676/10000)
# Epoch: 176 	Training Loss: 0.050765 	Validation Loss: 0.678488
# Training Accuracy (Overall): 98% (14737/15000)
# Validation Accuracy (Overall): 86% (8672/10000)
# Epoch: 177 	Training Loss: 0.043062 	Validation Loss: 0.669234
# Training Accuracy (Overall): 98% (14770/15000)
# Validation Accuracy (Overall): 87% (8766/10000)
# Epoch: 178 	Training Loss: 0.035254 	Validation Loss: 0.633124
# Training Accuracy (Overall): 98% (14829/15000)
# Validation Accuracy (Overall): 87% (8782/10000)
# Epoch: 179 	Training Loss: 0.036386 	Validation Loss: 0.633510
# Training Accuracy (Overall): 98% (14826/15000)
# Validation Accuracy (Overall): 87% (8793/10000)
# Epoch: 180 	Training Loss: 0.040601 	Validation Loss: 0.685000
# Training Accuracy (Overall): 98% (14797/15000)
# Validation Accuracy (Overall): 87% (8716/10000)
# Epoch: 181 	Training Loss: 0.045335 	Validation Loss: 0.655201
# Training Accuracy (Overall): 98% (14765/15000)
# Validation Accuracy (Overall): 87% (8761/10000)
# Epoch: 182 	Training Loss: 0.040233 	Validation Loss: 0.740096
# Training Accuracy (Overall): 98% (14797/15000)
# Validation Accuracy (Overall): 87% (8702/10000)
# Epoch: 183 	Training Loss: 0.043264 	Validation Loss: 0.653899
# Training Accuracy (Overall): 98% (14768/15000)
# Validation Accuracy (Overall): 87% (8776/10000)
# Epoch: 184 	Training Loss: 0.045282 	Validation Loss: 0.674395
# Training Accuracy (Overall): 98% (14778/15000)
# Validation Accuracy (Overall): 87% (8720/10000)
# Epoch: 185 	Training Loss: 0.049707 	Validation Loss: 0.677590
# Training Accuracy (Overall): 98% (14743/15000)
# Validation Accuracy (Overall): 87% (8739/10000)
# Epoch: 186 	Training Loss: 0.046870 	Validation Loss: 0.843924
# Training Accuracy (Overall): 98% (14760/15000)
# Validation Accuracy (Overall): 85% (8537/10000)
# Epoch: 187 	Training Loss: 0.040644 	Validation Loss: 0.670150
# Training Accuracy (Overall): 98% (14803/15000)
# Validation Accuracy (Overall): 87% (8773/10000)
# Epoch: 188 	Training Loss: 0.041296 	Validation Loss: 0.652268
# Training Accuracy (Overall): 98% (14793/15000)
# Validation Accuracy (Overall): 87% (8770/10000)
# Epoch: 189 	Training Loss: 0.040788 	Validation Loss: 0.699924
# Training Accuracy (Overall): 98% (14806/15000)
# Validation Accuracy (Overall): 87% (8711/10000)
# Epoch: 190 	Training Loss: 0.036120 	Validation Loss: 0.681330
# Training Accuracy (Overall): 98% (14839/15000)
# Validation Accuracy (Overall): 87% (8753/10000)
# Epoch: 191 	Training Loss: 0.040789 	Validation Loss: 0.678507
# Training Accuracy (Overall): 98% (14800/15000)
# Validation Accuracy (Overall): 87% (8780/10000)
# Epoch: 192 	Training Loss: 0.046439 	Validation Loss: 0.713003
# Training Accuracy (Overall): 98% (14777/15000)
# Validation Accuracy (Overall): 87% (8719/10000)
# Epoch: 193 	Training Loss: 0.045414 	Validation Loss: 0.718212
# Training Accuracy (Overall): 98% (14788/15000)
# Validation Accuracy (Overall): 87% (8711/10000)
# Epoch: 194 	Training Loss: 0.040538 	Validation Loss: 0.695048
# Training Accuracy (Overall): 98% (14793/15000)
# Validation Accuracy (Overall): 87% (8746/10000)
# Epoch: 195 	Training Loss: 0.044027 	Validation Loss: 0.661632
# Training Accuracy (Overall): 98% (14768/15000)
# Validation Accuracy (Overall): 87% (8761/10000)
# Epoch: 196 	Training Loss: 0.048003 	Validation Loss: 0.638780
# Training Accuracy (Overall): 98% (14760/15000)
# Validation Accuracy (Overall): 87% (8789/10000)
# Epoch: 197 	Training Loss: 0.040655 	Validation Loss: 0.665145
# Training Accuracy (Overall): 98% (14786/15000)
# Validation Accuracy (Overall): 87% (8751/10000)
# Epoch: 198 	Training Loss: 0.046350 	Validation Loss: 0.667375
# Training Accuracy (Overall): 98% (14764/15000)
# Validation Accuracy (Overall): 87% (8793/10000)
# Epoch: 199 	Training Loss: 0.040068 	Validation Loss: 0.764800
# Training Accuracy (Overall): 98% (14797/15000)
# Validation Accuracy (Overall): 86% (8656/10000)
# Test Loss: 0.762080
#
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 92% (929/1000)
# Test Accuracy of  bird: 80% (804/1000)
# Test Accuracy of   cat: 62% (625/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 75% (750/1000)
# Test Accuracy of  frog: 85% (858/1000)
# Test Accuracy of horse: 65% (657/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 80% (8014/10000)
# (1, 269722)
# 1
# ##########################################################
# #########################################################
# trial: 1
# tensor([ 8097, 38941, 38523,  ...,  1821, 44996, 14337])
# Epoch: 0 	Training Loss: 1.034737 	Validation Loss: 0.743484
# Training Accuracy (Overall): 72% (10846/15000)
# Validation Accuracy (Overall): 77% (7710/10000)
# Epoch: 1 	Training Loss: 0.670348 	Validation Loss: 0.638141
# Training Accuracy (Overall): 77% (11662/15000)
# Validation Accuracy (Overall): 79% (7922/10000)
# Epoch: 2 	Training Loss: 0.597995 	Validation Loss: 0.631882
# Training Accuracy (Overall): 79% (11944/15000)
# Validation Accuracy (Overall): 79% (7942/10000)
# Epoch: 3 	Training Loss: 0.580007 	Validation Loss: 0.622527
# Training Accuracy (Overall): 80% (12017/15000)
# Validation Accuracy (Overall): 79% (7974/10000)
# Epoch: 4 	Training Loss: 0.542477 	Validation Loss: 0.598644
# Training Accuracy (Overall): 81% (12248/15000)
# Validation Accuracy (Overall): 80% (8054/10000)
# Epoch: 5 	Training Loss: 0.526424 	Validation Loss: 0.547632
# Training Accuracy (Overall): 81% (12275/15000)
# Validation Accuracy (Overall): 81% (8165/10000)
# Epoch: 6 	Training Loss: 0.501412 	Validation Loss: 0.579445
# Training Accuracy (Overall): 82% (12429/15000)
# Validation Accuracy (Overall): 80% (8074/10000)
# Epoch: 7 	Training Loss: 0.489577 	Validation Loss: 0.526368
# Training Accuracy (Overall): 83% (12517/15000)
# Validation Accuracy (Overall): 82% (8270/10000)
# Epoch: 8 	Training Loss: 0.477835 	Validation Loss: 0.540615
# Training Accuracy (Overall): 83% (12525/15000)
# Validation Accuracy (Overall): 81% (8186/10000)
# Epoch: 9 	Training Loss: 0.452094 	Validation Loss: 0.543782
# Training Accuracy (Overall): 84% (12631/15000)
# Validation Accuracy (Overall): 82% (8213/10000)
# Epoch: 10 	Training Loss: 0.451367 	Validation Loss: 0.517196
# Training Accuracy (Overall): 84% (12641/15000)
# Validation Accuracy (Overall): 83% (8310/10000)
# Epoch: 11 	Training Loss: 0.426381 	Validation Loss: 0.563468
# Training Accuracy (Overall): 85% (12787/15000)
# Validation Accuracy (Overall): 81% (8195/10000)
# Epoch: 12 	Training Loss: 0.428698 	Validation Loss: 0.522277
# Training Accuracy (Overall): 85% (12771/15000)
# Validation Accuracy (Overall): 82% (8291/10000)
# Epoch: 13 	Training Loss: 0.413194 	Validation Loss: 0.533694
# Training Accuracy (Overall): 85% (12857/15000)
# Validation Accuracy (Overall): 82% (8269/10000)
# Epoch: 14 	Training Loss: 0.406179 	Validation Loss: 0.491881
# Training Accuracy (Overall): 85% (12863/15000)
# Validation Accuracy (Overall): 83% (8383/10000)
# Epoch: 15 	Training Loss: 0.392941 	Validation Loss: 0.556155
# Training Accuracy (Overall): 86% (12950/15000)
# Validation Accuracy (Overall): 82% (8216/10000)
# Epoch: 16 	Training Loss: 0.386425 	Validation Loss: 0.548817
# Training Accuracy (Overall): 86% (12956/15000)
# Validation Accuracy (Overall): 82% (8266/10000)
# Epoch: 17 	Training Loss: 0.378447 	Validation Loss: 0.507496
# Training Accuracy (Overall): 86% (13031/15000)
# Validation Accuracy (Overall): 83% (8361/10000)
# Epoch: 18 	Training Loss: 0.362459 	Validation Loss: 0.522036
# Training Accuracy (Overall): 87% (13072/15000)
# Validation Accuracy (Overall): 83% (8336/10000)
# Epoch: 19 	Training Loss: 0.354592 	Validation Loss: 0.512073
# Training Accuracy (Overall): 87% (13138/15000)
# Validation Accuracy (Overall): 83% (8373/10000)
# Epoch: 20 	Training Loss: 0.338591 	Validation Loss: 0.522337
# Training Accuracy (Overall): 88% (13214/15000)
# Validation Accuracy (Overall): 83% (8364/10000)
# Epoch: 21 	Training Loss: 0.345640 	Validation Loss: 0.550297
# Training Accuracy (Overall): 87% (13137/15000)
# Validation Accuracy (Overall): 83% (8327/10000)
# Epoch: 22 	Training Loss: 0.323364 	Validation Loss: 0.567591
# Training Accuracy (Overall): 88% (13309/15000)
# Validation Accuracy (Overall): 82% (8265/10000)
# Epoch: 23 	Training Loss: 0.321020 	Validation Loss: 0.540239
# Training Accuracy (Overall): 88% (13256/15000)
# Validation Accuracy (Overall): 83% (8330/10000)
# Epoch: 24 	Training Loss: 0.310813 	Validation Loss: 0.530672
# Training Accuracy (Overall): 88% (13328/15000)
# Validation Accuracy (Overall): 83% (8366/10000)
# Epoch: 25 	Training Loss: 0.307120 	Validation Loss: 0.519736
# Training Accuracy (Overall): 89% (13386/15000)
# Validation Accuracy (Overall): 84% (8416/10000)
# Epoch: 26 	Training Loss: 0.303815 	Validation Loss: 0.528230
# Training Accuracy (Overall): 89% (13424/15000)
# Validation Accuracy (Overall): 84% (8407/10000)
# Epoch: 27 	Training Loss: 0.296505 	Validation Loss: 0.523869
# Training Accuracy (Overall): 89% (13445/15000)
# Validation Accuracy (Overall): 84% (8422/10000)
# Epoch: 28 	Training Loss: 0.288729 	Validation Loss: 0.521012
# Training Accuracy (Overall): 89% (13465/15000)
# Validation Accuracy (Overall): 84% (8437/10000)
# Epoch: 29 	Training Loss: 0.276266 	Validation Loss: 0.506388
# Training Accuracy (Overall): 90% (13509/15000)
# Validation Accuracy (Overall): 85% (8504/10000)
# Epoch: 30 	Training Loss: 0.273964 	Validation Loss: 0.497350
# Training Accuracy (Overall): 90% (13561/15000)
# Validation Accuracy (Overall): 85% (8514/10000)
# Epoch: 31 	Training Loss: 0.265706 	Validation Loss: 0.547069
# Training Accuracy (Overall): 90% (13584/15000)
# Validation Accuracy (Overall): 83% (8389/10000)
# Epoch: 32 	Training Loss: 0.258556 	Validation Loss: 0.539388
# Training Accuracy (Overall): 91% (13660/15000)
# Validation Accuracy (Overall): 84% (8455/10000)
# Epoch: 33 	Training Loss: 0.256179 	Validation Loss: 0.501066
# Training Accuracy (Overall): 90% (13621/15000)
# Validation Accuracy (Overall): 85% (8512/10000)
# Epoch: 34 	Training Loss: 0.260881 	Validation Loss: 0.514113
# Training Accuracy (Overall): 90% (13595/15000)
# Validation Accuracy (Overall): 85% (8502/10000)
# Epoch: 35 	Training Loss: 0.245071 	Validation Loss: 0.575959
# Training Accuracy (Overall): 91% (13739/15000)
# Validation Accuracy (Overall): 83% (8356/10000)
# Epoch: 36 	Training Loss: 0.239200 	Validation Loss: 0.565309
# Training Accuracy (Overall): 91% (13756/15000)
# Validation Accuracy (Overall): 84% (8428/10000)
# Epoch: 37 	Training Loss: 0.231597 	Validation Loss: 0.556788
# Training Accuracy (Overall): 91% (13766/15000)
# Validation Accuracy (Overall): 84% (8444/10000)
# Epoch: 38 	Training Loss: 0.234710 	Validation Loss: 0.556608
# Training Accuracy (Overall): 91% (13746/15000)
# Validation Accuracy (Overall): 84% (8421/10000)
# Epoch: 39 	Training Loss: 0.229699 	Validation Loss: 0.558793
# Training Accuracy (Overall): 91% (13789/15000)
# Validation Accuracy (Overall): 84% (8409/10000)
# Epoch: 40 	Training Loss: 0.225129 	Validation Loss: 0.567943
# Training Accuracy (Overall): 91% (13792/15000)
# Validation Accuracy (Overall): 84% (8418/10000)
# Epoch: 41 	Training Loss: 0.216479 	Validation Loss: 0.580945
# Training Accuracy (Overall): 92% (13874/15000)
# Validation Accuracy (Overall): 83% (8392/10000)
# Epoch: 42 	Training Loss: 0.209539 	Validation Loss: 0.559616
# Training Accuracy (Overall): 92% (13911/15000)
# Validation Accuracy (Overall): 84% (8450/10000)
# Epoch: 43 	Training Loss: 0.214304 	Validation Loss: 0.589161
# Training Accuracy (Overall): 92% (13870/15000)
# Validation Accuracy (Overall): 83% (8373/10000)
# Epoch: 44 	Training Loss: 0.196451 	Validation Loss: 0.529034
# Training Accuracy (Overall): 93% (13971/15000)
# Validation Accuracy (Overall): 85% (8572/10000)
# Epoch: 45 	Training Loss: 0.194999 	Validation Loss: 0.518760
# Training Accuracy (Overall): 93% (13973/15000)
# Validation Accuracy (Overall): 85% (8566/10000)
# Epoch: 46 	Training Loss: 0.186252 	Validation Loss: 0.529181
# Training Accuracy (Overall): 93% (14008/15000)
# Validation Accuracy (Overall): 85% (8548/10000)
# Epoch: 47 	Training Loss: 0.189173 	Validation Loss: 0.516248
# Training Accuracy (Overall): 93% (13993/15000)
# Validation Accuracy (Overall): 86% (8600/10000)
# Epoch: 48 	Training Loss: 0.185203 	Validation Loss: 0.535963
# Training Accuracy (Overall): 93% (14042/15000)
# Validation Accuracy (Overall): 86% (8602/10000)
# Epoch: 49 	Training Loss: 0.187653 	Validation Loss: 0.532937
# Training Accuracy (Overall): 93% (13992/15000)
# Validation Accuracy (Overall): 85% (8583/10000)
# Epoch: 50 	Training Loss: 0.176443 	Validation Loss: 0.587222
# Training Accuracy (Overall): 93% (14058/15000)
# Validation Accuracy (Overall): 84% (8473/10000)
# Epoch: 51 	Training Loss: 0.171839 	Validation Loss: 0.515190
# Training Accuracy (Overall): 93% (14089/15000)
# Validation Accuracy (Overall): 86% (8628/10000)
# Epoch: 52 	Training Loss: 0.168940 	Validation Loss: 0.509337
# Training Accuracy (Overall): 94% (14118/15000)
# Validation Accuracy (Overall): 86% (8656/10000)
# Epoch: 53 	Training Loss: 0.160835 	Validation Loss: 0.566371
# Training Accuracy (Overall): 94% (14136/15000)
# Validation Accuracy (Overall): 85% (8569/10000)
# Epoch: 54 	Training Loss: 0.167036 	Validation Loss: 0.584275
# Training Accuracy (Overall): 94% (14103/15000)
# Validation Accuracy (Overall): 85% (8504/10000)
# Epoch: 55 	Training Loss: 0.170485 	Validation Loss: 0.568383
# Training Accuracy (Overall): 94% (14119/15000)
# Validation Accuracy (Overall): 85% (8502/10000)
# Epoch: 56 	Training Loss: 0.161827 	Validation Loss: 0.584233
# Training Accuracy (Overall): 94% (14137/15000)
# Validation Accuracy (Overall): 85% (8555/10000)
# Epoch: 57 	Training Loss: 0.156062 	Validation Loss: 0.557250
# Training Accuracy (Overall): 94% (14166/15000)
# Validation Accuracy (Overall): 85% (8556/10000)
# Epoch: 58 	Training Loss: 0.148384 	Validation Loss: 0.535123
# Training Accuracy (Overall): 94% (14215/15000)
# Validation Accuracy (Overall): 86% (8649/10000)
# Epoch: 59 	Training Loss: 0.147447 	Validation Loss: 0.538565
# Training Accuracy (Overall): 94% (14219/15000)
# Validation Accuracy (Overall): 86% (8657/10000)
# Epoch: 60 	Training Loss: 0.151472 	Validation Loss: 0.545277
# Training Accuracy (Overall): 94% (14172/15000)
# Validation Accuracy (Overall): 86% (8616/10000)
# Epoch: 61 	Training Loss: 0.150668 	Validation Loss: 0.582753
# Training Accuracy (Overall): 94% (14183/15000)
# Validation Accuracy (Overall): 85% (8545/10000)
# Epoch: 62 	Training Loss: 0.147186 	Validation Loss: 0.538443
# Training Accuracy (Overall): 94% (14183/15000)
# Validation Accuracy (Overall): 86% (8642/10000)
# Epoch: 63 	Training Loss: 0.144410 	Validation Loss: 0.599827
# Training Accuracy (Overall): 94% (14231/15000)
# Validation Accuracy (Overall): 85% (8576/10000)
# Epoch: 64 	Training Loss: 0.141543 	Validation Loss: 0.565153
# Training Accuracy (Overall): 94% (14231/15000)
# Validation Accuracy (Overall): 86% (8627/10000)
# Epoch: 65 	Training Loss: 0.138583 	Validation Loss: 0.597888
# Training Accuracy (Overall): 95% (14288/15000)
# Validation Accuracy (Overall): 85% (8551/10000)
# Epoch: 66 	Training Loss: 0.132415 	Validation Loss: 0.578906
# Training Accuracy (Overall): 95% (14306/15000)
# Validation Accuracy (Overall): 85% (8599/10000)
# Epoch: 67 	Training Loss: 0.134150 	Validation Loss: 0.569704
# Training Accuracy (Overall): 95% (14287/15000)
# Validation Accuracy (Overall): 86% (8645/10000)
# Epoch: 68 	Training Loss: 0.125153 	Validation Loss: 0.656659
# Training Accuracy (Overall): 95% (14368/15000)
# Validation Accuracy (Overall): 84% (8472/10000)
# Epoch: 69 	Training Loss: 0.129465 	Validation Loss: 0.567668
# Training Accuracy (Overall): 95% (14304/15000)
# Validation Accuracy (Overall): 86% (8696/10000)
# Epoch: 70 	Training Loss: 0.118684 	Validation Loss: 0.588561
# Training Accuracy (Overall): 95% (14379/15000)
# Validation Accuracy (Overall): 86% (8610/10000)
# Epoch: 71 	Training Loss: 0.128242 	Validation Loss: 0.626838
# Training Accuracy (Overall): 95% (14338/15000)
# Validation Accuracy (Overall): 85% (8598/10000)
# Epoch: 72 	Training Loss: 0.116006 	Validation Loss: 0.570670
# Training Accuracy (Overall): 96% (14400/15000)
# Validation Accuracy (Overall): 86% (8664/10000)
# Epoch: 73 	Training Loss: 0.127526 	Validation Loss: 0.581414
# Training Accuracy (Overall): 95% (14310/15000)
# Validation Accuracy (Overall): 86% (8629/10000)
# Epoch: 74 	Training Loss: 0.118929 	Validation Loss: 0.617178
# Training Accuracy (Overall): 95% (14377/15000)
# Validation Accuracy (Overall): 85% (8571/10000)
# Epoch: 75 	Training Loss: 0.107998 	Validation Loss: 0.586099
# Training Accuracy (Overall): 96% (14432/15000)
# Validation Accuracy (Overall): 86% (8611/10000)
# Epoch: 76 	Training Loss: 0.117693 	Validation Loss: 0.610680
# Training Accuracy (Overall): 95% (14395/15000)
# Validation Accuracy (Overall): 85% (8556/10000)
# Epoch: 77 	Training Loss: 0.118714 	Validation Loss: 0.612502
# Training Accuracy (Overall): 95% (14362/15000)
# Validation Accuracy (Overall): 86% (8634/10000)
# Epoch: 78 	Training Loss: 0.110855 	Validation Loss: 0.608059
# Training Accuracy (Overall): 96% (14421/15000)
# Validation Accuracy (Overall): 86% (8643/10000)
# Epoch: 79 	Training Loss: 0.109082 	Validation Loss: 0.720649
# Training Accuracy (Overall): 96% (14448/15000)
# Validation Accuracy (Overall): 84% (8414/10000)
# Epoch: 80 	Training Loss: 0.100929 	Validation Loss: 0.687259
# Training Accuracy (Overall): 96% (14459/15000)
# Validation Accuracy (Overall): 85% (8542/10000)
# Epoch: 81 	Training Loss: 0.109121 	Validation Loss: 0.593242
# Training Accuracy (Overall): 96% (14406/15000)
# Validation Accuracy (Overall): 86% (8687/10000)
# Epoch: 82 	Training Loss: 0.110807 	Validation Loss: 0.597532
# Training Accuracy (Overall): 96% (14411/15000)
# Validation Accuracy (Overall): 86% (8665/10000)
# Epoch: 83 	Training Loss: 0.101194 	Validation Loss: 0.634685
# Training Accuracy (Overall): 96% (14465/15000)
# Validation Accuracy (Overall): 85% (8554/10000)
# Epoch: 84 	Training Loss: 0.101770 	Validation Loss: 0.625698
# Training Accuracy (Overall): 96% (14454/15000)
# Validation Accuracy (Overall): 86% (8640/10000)
# Epoch: 85 	Training Loss: 0.100239 	Validation Loss: 0.637310
# Training Accuracy (Overall): 96% (14479/15000)
# Validation Accuracy (Overall): 86% (8605/10000)
# Epoch: 86 	Training Loss: 0.102558 	Validation Loss: 0.587991
# Training Accuracy (Overall): 96% (14478/15000)
# Validation Accuracy (Overall): 86% (8659/10000)
# Epoch: 87 	Training Loss: 0.089888 	Validation Loss: 0.591078
# Training Accuracy (Overall): 96% (14522/15000)
# Validation Accuracy (Overall): 87% (8704/10000)
# Epoch: 88 	Training Loss: 0.091304 	Validation Loss: 0.588780
# Training Accuracy (Overall): 96% (14523/15000)
# Validation Accuracy (Overall): 86% (8672/10000)
# Epoch: 89 	Training Loss: 0.098089 	Validation Loss: 0.607419
# Training Accuracy (Overall): 96% (14487/15000)
# Validation Accuracy (Overall): 87% (8710/10000)
# Epoch: 90 	Training Loss: 0.102546 	Validation Loss: 0.660456
# Training Accuracy (Overall): 96% (14456/15000)
# Validation Accuracy (Overall): 85% (8566/10000)
# Epoch: 91 	Training Loss: 0.092124 	Validation Loss: 0.596687
# Training Accuracy (Overall): 96% (14514/15000)
# Validation Accuracy (Overall): 86% (8644/10000)
# Epoch: 92 	Training Loss: 0.086468 	Validation Loss: 0.636395
# Training Accuracy (Overall): 96% (14534/15000)
# Validation Accuracy (Overall): 86% (8619/10000)
# Epoch: 93 	Training Loss: 0.087489 	Validation Loss: 0.655998
# Training Accuracy (Overall): 97% (14553/15000)
# Validation Accuracy (Overall): 86% (8642/10000)
# Epoch: 94 	Training Loss: 0.092568 	Validation Loss: 0.635465
# Training Accuracy (Overall): 96% (14523/15000)
# Validation Accuracy (Overall): 86% (8660/10000)
# Epoch: 95 	Training Loss: 0.091003 	Validation Loss: 0.646707
# Training Accuracy (Overall): 96% (14505/15000)
# Validation Accuracy (Overall): 86% (8601/10000)
# Epoch: 96 	Training Loss: 0.092234 	Validation Loss: 0.608866
# Training Accuracy (Overall): 96% (14523/15000)
# Validation Accuracy (Overall): 86% (8667/10000)
# Epoch: 97 	Training Loss: 0.087874 	Validation Loss: 0.732065
# Training Accuracy (Overall): 96% (14535/15000)
# Validation Accuracy (Overall): 84% (8451/10000)
# Epoch: 98 	Training Loss: 0.094975 	Validation Loss: 0.658344
# Training Accuracy (Overall): 96% (14500/15000)
# Validation Accuracy (Overall): 86% (8620/10000)
# Epoch: 99 	Training Loss: 0.092773 	Validation Loss: 0.597319
# Training Accuracy (Overall): 96% (14520/15000)
# ...
# Validation Accuracy (Overall): 87% (8707/10000)
# Epoch: 128 	Training Loss: 0.070152 	Validation Loss: 0.642549
# Training Accuracy (Overall): 97% (14637/15000)
# Validation Accuracy (Overall): 87% (8715/10000)
# Epoch: 129 	Training Loss: 0.064463 	Validation Loss: 0.653781
# Training Accuracy (Overall): 97% (14669/15000)
# Validation Accuracy (Overall): 86% (8675/10000)
# Epoch: 130 	Training Loss: 0.063548 	Validation Loss: 0.678429
# Training Accuracy (Overall): 97% (14680/15000)
# Validation Accuracy (Overall): 86% (8690/10000)
# Epoch: 131 	Training Loss: 0.059445 	Validation Loss: 0.616668
# Training Accuracy (Overall): 97% (14698/15000)
# Validation Accuracy (Overall): 87% (8721/10000)
# Epoch: 132 	Training Loss: 0.053598 	Validation Loss: 0.681702
# Training Accuracy (Overall): 98% (14731/15000)
# Validation Accuracy (Overall): 87% (8727/10000)
# Epoch: 133 	Training Loss: 0.054714 	Validation Loss: 0.674113
# Training Accuracy (Overall): 98% (14727/15000)
# Validation Accuracy (Overall): 86% (8684/10000)
# Epoch: 134 	Training Loss: 0.050754 	Validation Loss: 0.686221
# Training Accuracy (Overall): 98% (14735/15000)
# Validation Accuracy (Overall): 86% (8689/10000)
# Epoch: 135 	Training Loss: 0.049172 	Validation Loss: 0.626406
# Training Accuracy (Overall): 98% (14737/15000)
# Validation Accuracy (Overall): 87% (8759/10000)
# Epoch: 136 	Training Loss: 0.054686 	Validation Loss: 0.683392
# Training Accuracy (Overall): 98% (14724/15000)
# Validation Accuracy (Overall): 86% (8665/10000)
# Epoch: 137 	Training Loss: 0.066883 	Validation Loss: 0.651148
# Training Accuracy (Overall): 97% (14668/15000)
# Validation Accuracy (Overall): 87% (8735/10000)
# Epoch: 138 	Training Loss: 0.068136 	Validation Loss: 0.648757
# Training Accuracy (Overall): 97% (14633/15000)
# Validation Accuracy (Overall): 86% (8675/10000)
# Epoch: 139 	Training Loss: 0.063641 	Validation Loss: 0.655799
# Training Accuracy (Overall): 97% (14669/15000)
# Validation Accuracy (Overall): 86% (8687/10000)
# Epoch: 140 	Training Loss: 0.067806 	Validation Loss: 0.680962
# Training Accuracy (Overall): 97% (14631/15000)
# Validation Accuracy (Overall): 86% (8676/10000)
# Epoch: 141 	Training Loss: 0.072202 	Validation Loss: 0.683213
# Training Accuracy (Overall): 97% (14620/15000)
# Validation Accuracy (Overall): 87% (8723/10000)
# Epoch: 142 	Training Loss: 0.067337 	Validation Loss: 0.640922
# Training Accuracy (Overall): 97% (14646/15000)
# Validation Accuracy (Overall): 87% (8744/10000)
# Epoch: 143 	Training Loss: 0.062445 	Validation Loss: 0.614361
# Training Accuracy (Overall): 97% (14645/15000)
# Validation Accuracy (Overall): 87% (8785/10000)
# Epoch: 144 	Training Loss: 0.049824 	Validation Loss: 0.589527
# Training Accuracy (Overall): 98% (14752/15000)
# Validation Accuracy (Overall): 88% (8808/10000)
# Epoch: 145 	Training Loss: 0.059129 	Validation Loss: 0.655050
# Training Accuracy (Overall): 97% (14679/15000)
# Validation Accuracy (Overall): 87% (8755/10000)
# Epoch: 146 	Training Loss: 0.060488 	Validation Loss: 0.616262
# Training Accuracy (Overall): 97% (14684/15000)
# Validation Accuracy (Overall): 88% (8812/10000)
# Epoch: 147 	Training Loss: 0.046530 	Validation Loss: 0.628815
# Training Accuracy (Overall): 98% (14789/15000)
# Validation Accuracy (Overall): 87% (8734/10000)
# Epoch: 148 	Training Loss: 0.049093 	Validation Loss: 0.641657
# Training Accuracy (Overall): 98% (14745/15000)
# Validation Accuracy (Overall): 88% (8801/10000)
# Epoch: 149 	Training Loss: 0.050797 	Validation Loss: 0.682310
# Training Accuracy (Overall): 98% (14731/15000)
# Validation Accuracy (Overall): 87% (8707/10000)
# Epoch: 150 	Training Loss: 0.049444 	Validation Loss: 0.664134
# Training Accuracy (Overall): 98% (14752/15000)
# Validation Accuracy (Overall): 87% (8714/10000)
# Epoch: 151 	Training Loss: 0.053567 	Validation Loss: 0.643740
# Training Accuracy (Overall): 98% (14737/15000)
# Validation Accuracy (Overall): 87% (8771/10000)
# Epoch: 152 	Training Loss: 0.051983 	Validation Loss: 0.661531
# Training Accuracy (Overall): 98% (14736/15000)
# Validation Accuracy (Overall): 87% (8741/10000)
# Epoch: 153 	Training Loss: 0.050373 	Validation Loss: 0.697980
# Training Accuracy (Overall): 98% (14739/15000)
# Validation Accuracy (Overall): 87% (8719/10000)
# Epoch: 154 	Training Loss: 0.052590 	Validation Loss: 0.669379
# Training Accuracy (Overall): 98% (14720/15000)
# Validation Accuracy (Overall): 87% (8715/10000)
# Epoch: 155 	Training Loss: 0.049703 	Validation Loss: 0.658292
# Training Accuracy (Overall): 98% (14749/15000)
# Validation Accuracy (Overall): 87% (8765/10000)
# Epoch: 156 	Training Loss: 0.053511 	Validation Loss: 0.675557
# Training Accuracy (Overall): 98% (14729/15000)
# Validation Accuracy (Overall): 87% (8724/10000)
# Epoch: 157 	Training Loss: 0.054620 	Validation Loss: 0.661606
# Training Accuracy (Overall): 98% (14726/15000)
# Validation Accuracy (Overall): 87% (8741/10000)
# Epoch: 158 	Training Loss: 0.060587 	Validation Loss: 0.680617
# Training Accuracy (Overall): 97% (14675/15000)
# Validation Accuracy (Overall): 87% (8725/10000)
# Epoch: 159 	Training Loss: 0.053548 	Validation Loss: 0.692918
# Training Accuracy (Overall): 98% (14724/15000)
# Validation Accuracy (Overall): 87% (8755/10000)
# Epoch: 160 	Training Loss: 0.049495 	Validation Loss: 0.662977
# Training Accuracy (Overall): 98% (14733/15000)
# Validation Accuracy (Overall): 87% (8758/10000)
# Epoch: 161 	Training Loss: 0.050949 	Validation Loss: 0.672094
# Training Accuracy (Overall): 98% (14726/15000)
# Validation Accuracy (Overall): 87% (8724/10000)
# Epoch: 162 	Training Loss: 0.050477 	Validation Loss: 0.697759
# Training Accuracy (Overall): 98% (14739/15000)
# Validation Accuracy (Overall): 86% (8680/10000)
# Epoch: 163 	Training Loss: 0.047412 	Validation Loss: 0.624629
# Training Accuracy (Overall): 98% (14759/15000)
# Validation Accuracy (Overall): 87% (8796/10000)
# Epoch: 164 	Training Loss: 0.050739 	Validation Loss: 0.654192
# Training Accuracy (Overall): 98% (14715/15000)
# Validation Accuracy (Overall): 87% (8786/10000)
# Epoch: 165 	Training Loss: 0.045590 	Validation Loss: 0.616538
# Training Accuracy (Overall): 98% (14764/15000)
# Validation Accuracy (Overall): 88% (8803/10000)
# Epoch: 166 	Training Loss: 0.052381 	Validation Loss: 0.634617
# Training Accuracy (Overall): 98% (14738/15000)
# Validation Accuracy (Overall): 87% (8798/10000)
# Epoch: 167 	Training Loss: 0.045938 	Validation Loss: 0.645314
# Training Accuracy (Overall): 98% (14776/15000)
# Validation Accuracy (Overall): 88% (8804/10000)
# Epoch: 168 	Training Loss: 0.045928 	Validation Loss: 0.677613
# Training Accuracy (Overall): 98% (14770/15000)
# Validation Accuracy (Overall): 87% (8738/10000)
# Epoch: 169 	Training Loss: 0.051690 	Validation Loss: 0.728094
# Training Accuracy (Overall): 98% (14747/15000)
# Validation Accuracy (Overall): 86% (8667/10000)
# Epoch: 170 	Training Loss: 0.052109 	Validation Loss: 0.663821
# Training Accuracy (Overall): 98% (14720/15000)
# Validation Accuracy (Overall): 87% (8753/10000)
# Epoch: 171 	Training Loss: 0.057192 	Validation Loss: 0.665652
# Training Accuracy (Overall): 98% (14703/15000)
# Validation Accuracy (Overall): 87% (8728/10000)
# Epoch: 172 	Training Loss: 0.050281 	Validation Loss: 0.640107
# Training Accuracy (Overall): 98% (14745/15000)
# Validation Accuracy (Overall): 87% (8780/10000)
# Epoch: 173 	Training Loss: 0.047808 	Validation Loss: 0.635416
# Training Accuracy (Overall): 98% (14755/15000)
# Validation Accuracy (Overall): 87% (8794/10000)
# Epoch: 174 	Training Loss: 0.047793 	Validation Loss: 0.701407
# Training Accuracy (Overall): 98% (14753/15000)
# Validation Accuracy (Overall): 87% (8716/10000)
# Epoch: 175 	Training Loss: 0.047157 	Validation Loss: 0.665339
# Training Accuracy (Overall): 98% (14765/15000)
# Validation Accuracy (Overall): 87% (8735/10000)
# Epoch: 176 	Training Loss: 0.044445 	Validation Loss: 0.669643
# Training Accuracy (Overall): 98% (14768/15000)
# Validation Accuracy (Overall): 87% (8735/10000)
# Epoch: 177 	Training Loss: 0.046394 	Validation Loss: 0.672575
# Training Accuracy (Overall): 98% (14767/15000)
# Validation Accuracy (Overall): 87% (8785/10000)
# Epoch: 178 	Training Loss: 0.044559 	Validation Loss: 0.654396
# Training Accuracy (Overall): 98% (14769/15000)
# Validation Accuracy (Overall): 87% (8789/10000)
# Epoch: 179 	Training Loss: 0.045965 	Validation Loss: 0.642750
# Training Accuracy (Overall): 98% (14753/15000)
# Validation Accuracy (Overall): 88% (8810/10000)
# Epoch: 180 	Training Loss: 0.040825 	Validation Loss: 0.638498
# Training Accuracy (Overall): 98% (14799/15000)
# Validation Accuracy (Overall): 88% (8847/10000)
# Epoch: 181 	Training Loss: 0.041828 	Validation Loss: 0.670305
# Training Accuracy (Overall): 98% (14789/15000)
# Validation Accuracy (Overall): 87% (8761/10000)
# Epoch: 182 	Training Loss: 0.040195 	Validation Loss: 0.694560
# Training Accuracy (Overall): 98% (14798/15000)
# Validation Accuracy (Overall): 87% (8708/10000)
# Epoch: 183 	Training Loss: 0.052292 	Validation Loss: 0.647588
# Training Accuracy (Overall): 98% (14755/15000)
# Validation Accuracy (Overall): 87% (8793/10000)
# Epoch: 184 	Training Loss: 0.044607 	Validation Loss: 0.651308
# Training Accuracy (Overall): 98% (14774/15000)
# Validation Accuracy (Overall): 88% (8844/10000)
# Epoch: 185 	Training Loss: 0.038577 	Validation Loss: 0.666544
# Training Accuracy (Overall): 98% (14816/15000)
# Validation Accuracy (Overall): 87% (8790/10000)
# Epoch: 186 	Training Loss: 0.045151 	Validation Loss: 0.684846
# Training Accuracy (Overall): 98% (14766/15000)
# Validation Accuracy (Overall): 87% (8712/10000)
# Epoch: 187 	Training Loss: 0.049698 	Validation Loss: 0.710941
# Training Accuracy (Overall): 98% (14749/15000)
# Validation Accuracy (Overall): 87% (8729/10000)
# Epoch: 188 	Training Loss: 0.046982 	Validation Loss: 0.637227
# Training Accuracy (Overall): 98% (14753/15000)
# Validation Accuracy (Overall): 87% (8796/10000)
# Epoch: 189 	Training Loss: 0.040015 	Validation Loss: 0.679054
# Training Accuracy (Overall): 98% (14799/15000)
# Validation Accuracy (Overall): 87% (8762/10000)
# Epoch: 190 	Training Loss: 0.041420 	Validation Loss: 0.652468
# Training Accuracy (Overall): 98% (14796/15000)
# Validation Accuracy (Overall): 87% (8772/10000)
# Epoch: 191 	Training Loss: 0.041945 	Validation Loss: 0.656739
# Training Accuracy (Overall): 98% (14788/15000)
# Validation Accuracy (Overall): 87% (8783/10000)
# Epoch: 192 	Training Loss: 0.045289 	Validation Loss: 0.620269
# Training Accuracy (Overall): 98% (14766/15000)
# Validation Accuracy (Overall): 88% (8821/10000)
# Epoch: 193 	Training Loss: 0.037748 	Validation Loss: 0.710490
# Training Accuracy (Overall): 98% (14819/15000)
# Validation Accuracy (Overall): 87% (8700/10000)
# Epoch: 194 	Training Loss: 0.037699 	Validation Loss: 0.700360
# Training Accuracy (Overall): 98% (14790/15000)
# Validation Accuracy (Overall): 87% (8738/10000)
# Epoch: 195 	Training Loss: 0.039866 	Validation Loss: 0.667801
# Training Accuracy (Overall): 98% (14800/15000)
# Validation Accuracy (Overall): 88% (8808/10000)
# Epoch: 196 	Training Loss: 0.042663 	Validation Loss: 0.645142
# Training Accuracy (Overall): 98% (14786/15000)
# Validation Accuracy (Overall): 88% (8822/10000)
# Epoch: 197 	Training Loss: 0.040581 	Validation Loss: 0.624137
# Training Accuracy (Overall): 98% (14783/15000)
# Validation Accuracy (Overall): 88% (8875/10000)
# Epoch: 198 	Training Loss: 0.037346 	Validation Loss: 0.662371
# Training Accuracy (Overall): 98% (14809/15000)
# Validation Accuracy (Overall): 88% (8814/10000)
# Epoch: 199 	Training Loss: 0.043457 	Validation Loss: 0.707293
# Training Accuracy (Overall): 98% (14779/15000)
# Validation Accuracy (Overall): 87% (8713/10000)
# Test Loss: 0.729266
#
# Test Accuracy of airplane: 82% (825/1000)
# Test Accuracy of automobile: 91% (914/1000)
# Test Accuracy of  bird: 75% (753/1000)
# Test Accuracy of   cat: 80% (807/1000)
# Test Accuracy of  deer: 73% (738/1000)
# Test Accuracy of   dog: 62% (622/1000)
# Test Accuracy of  frog: 84% (847/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 80% (8085/10000)
# (1, 269722)
# 9
# ##########################################################
# #########################################################
# trial: 9
# tensor([10079, 26421, 23136,  ..., 20257, 31967, 39571])
# Epoch: 0 	Training Loss: 1.021071 	Validation Loss: 0.768097
# Training Accuracy (Overall): 72% (10897/15000)
# Validation Accuracy (Overall): 77% (7731/10000)
# Epoch: 1 	Training Loss: 0.665555 	Validation Loss: 0.624765
# Training Accuracy (Overall): 77% (11681/15000)
# Validation Accuracy (Overall): 79% (7982/10000)
# Epoch: 2 	Training Loss: 0.589180 	Validation Loss: 0.615870
# Training Accuracy (Overall): 80% (12007/15000)
# Validation Accuracy (Overall): 79% (7983/10000)
# Epoch: 3 	Training Loss: 0.562424 	Validation Loss: 0.585358
# Training Accuracy (Overall): 80% (12102/15000)
# Validation Accuracy (Overall): 80% (8056/10000)
# Epoch: 4 	Training Loss: 0.542779 	Validation Loss: 0.574137
# Training Accuracy (Overall): 81% (12165/15000)
# Validation Accuracy (Overall): 80% (8087/10000)
# Epoch: 5 	Training Loss: 0.512186 	Validation Loss: 0.546884
# Training Accuracy (Overall): 82% (12351/15000)
# Validation Accuracy (Overall): 82% (8222/10000)
# Epoch: 6 	Training Loss: 0.500600 	Validation Loss: 0.561956
# Training Accuracy (Overall): 82% (12422/15000)
# Validation Accuracy (Overall): 81% (8167/10000)
# Epoch: 7 	Training Loss: 0.490456 	Validation Loss: 0.531405
# Training Accuracy (Overall): 83% (12481/15000)
# Validation Accuracy (Overall): 82% (8218/10000)
# Epoch: 8 	Training Loss: 0.463923 	Validation Loss: 0.535729
# Training Accuracy (Overall): 83% (12589/15000)
# Validation Accuracy (Overall): 82% (8231/10000)
# Epoch: 9 	Training Loss: 0.456585 	Validation Loss: 0.542044
# Training Accuracy (Overall): 84% (12605/15000)
# Validation Accuracy (Overall): 82% (8215/10000)
# Epoch: 10 	Training Loss: 0.437622 	Validation Loss: 0.521647
# Training Accuracy (Overall): 84% (12748/15000)
# Validation Accuracy (Overall): 83% (8325/10000)
# Epoch: 11 	Training Loss: 0.427586 	Validation Loss: 0.552425
# Training Accuracy (Overall): 85% (12774/15000)
# Validation Accuracy (Overall): 81% (8196/10000)
# Epoch: 12 	Training Loss: 0.419698 	Validation Loss: 0.530999
# Training Accuracy (Overall): 85% (12817/15000)
# Validation Accuracy (Overall): 82% (8298/10000)
# Epoch: 13 	Training Loss: 0.415501 	Validation Loss: 0.517829
# Training Accuracy (Overall): 85% (12830/15000)
# Validation Accuracy (Overall): 83% (8320/10000)
# Epoch: 14 	Training Loss: 0.394641 	Validation Loss: 0.498488
# Training Accuracy (Overall): 86% (12938/15000)
# Validation Accuracy (Overall): 83% (8374/10000)
# Epoch: 15 	Training Loss: 0.382908 	Validation Loss: 0.591253
# Training Accuracy (Overall): 86% (12956/15000)
# Validation Accuracy (Overall): 81% (8147/10000)
# Epoch: 16 	Training Loss: 0.379856 	Validation Loss: 0.506242
# Training Accuracy (Overall): 86% (12980/15000)
# Validation Accuracy (Overall): 83% (8373/10000)
# Epoch: 17 	Training Loss: 0.373167 	Validation Loss: 0.551881
# Training Accuracy (Overall): 87% (13058/15000)
# Validation Accuracy (Overall): 83% (8300/10000)
# Epoch: 18 	Training Loss: 0.357012 	Validation Loss: 0.557389
# Training Accuracy (Overall): 87% (13160/15000)
# Validation Accuracy (Overall): 82% (8230/10000)
# Epoch: 19 	Training Loss: 0.350235 	Validation Loss: 0.551484
# Training Accuracy (Overall): 87% (13142/15000)
# Validation Accuracy (Overall): 83% (8307/10000)
# Epoch: 20 	Training Loss: 0.339193 	Validation Loss: 0.498379
# Training Accuracy (Overall): 87% (13192/15000)
# Validation Accuracy (Overall): 84% (8438/10000)
# Epoch: 21 	Training Loss: 0.330595 	Validation Loss: 0.533722
# Training Accuracy (Overall): 88% (13268/15000)
# Validation Accuracy (Overall): 83% (8377/10000)
# Epoch: 22 	Training Loss: 0.323380 	Validation Loss: 0.527740
# Training Accuracy (Overall): 88% (13300/15000)
# Validation Accuracy (Overall): 83% (8376/10000)
# Epoch: 23 	Training Loss: 0.311231 	Validation Loss: 0.503500
# Training Accuracy (Overall): 89% (13361/15000)
# Validation Accuracy (Overall): 84% (8463/10000)
# Epoch: 24 	Training Loss: 0.318550 	Validation Loss: 0.528108
# Training Accuracy (Overall): 88% (13299/15000)
# Validation Accuracy (Overall): 83% (8385/10000)

# %%
np.save('10matrix7to15.npy', matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 np.save('10matrix7to15.npy', matrix)
#
# NameError: name 'matrix' is not defined

# %%
def get_eig_of_differences(data):
    """
    data should be a 2-dimensional tensor whose rows are the trained parameters
    of an ML model, with one training per row. If you have a model with N
    parameters that you run M times, data should be of size (M, N). Returns a
    1-dimensional, M-element tensor whose entries are the eigenvalues (in no
    particular order) of the square matrix calculated by subtracting the mean
    of the input rows from each individual row, then right-multiplying that
    matrix by its transpose. This guarantees a M by M square matrix, which
    means that calculating the eigenvalues is surprisingly fast, even with
    reasonably large models.
    """
    mu = torch.mean(data, 0, keepdim=True).expand(data.size()[0], -1)
    deviation_data = data-mu
    square_data = torch.matmul(deviation_data, deviation_data.transpose(0, 1))
    eig = torch.linalg.eigvals(square_data)
    return eig.real

def get_gaussian_covariance(data):
    cov = torch.cov(data.t()) 
    U, S, V = torch.linalg.svd(cov)
    T = torch.nansum(torch.sqrt(S))
    for i in range(5130):
        S[i] = math.sqrt(S[i])*T
    S = torch.diag(S)
    temp = torch.matmul(U, S)
    return torch.matmul(S,V)

def get_gaussian(data):
    cov = torch.cov(data.t()) 
    U, S, V = torch.linalg.svd(cov)
    T = torch.nansum(torch.sqrt(S))
    for i in range(5130):
        S[i] = math.sqrt(S[i])*T
    return S
    
def get_l2_norm(data):
    mu = torch.mean(data, 0, keepdim=True).expand(data.size()[0], -1)
    deviation_data = data-mu
    total_norm = 0.0
    for row in deviation_data:
        norm = torch.norm(row, p=2)
        norm *= norm
        total_norm += norm
    return total_norm / data.size()[0]

def get_sample_covariance_eigs(data):
    cov = torch.cov(data.t()) # torch.cov expects columns, not rows, to be individual trials
    print(cov.size())
    #eig = torch.linalg.eigvals(cov)
    U, S, V = torch.linalg.svd(cov)
    return S
    #return eig.real

def l2norm(data): 
    matrix = data.numpy()
    count = 0
    total = 0
    for i in range(10):
        for j in range(i+1, 10):
            data1 = matrix[i]
            data2 = matrix[j]
            print(np.shape(data1))
            difference = data1 -data2
            print(type(difference))
            total += np.linalg.norm(difference)
            
            count = count+1
    print(total/count)
    print(np.linalg.norm(matrix[0]))
    print((total/count)/np.linalg.norm(matrix[0]))
    
            
def get_eig_of_differences_fast(data, num_eigvals=-1):
    """
    ONLY USE THIS FUNCTION AFTER RUNNING AN EXCESSIVE (>10,000) NUMBER OF TRIALS
    Acts similarly to get_eig_of_differences, except that it averages the N by N
    square matrix whose eigenvalues are calculated with its transpose, then uses
    torch.lobpcg to estimate only the num_eigvals largest eigenvalues, instead
    of calculating all of them. num_eigvals defaults to data.size()[0]
    """
    mu = torch.mean(data, 0, keepdim=True).expand(data.size()[0], -1)
    deviation_data = data-mu
    square_data = torch.matmul(deviation_data, deviation_data.transpose(0, 1))
    square_data = (square_data+square_data.transpose(0, 1))/2
    eigvals_to_gen = data.size()[0] if num_eigvals == -1 else num_eigvals
    eig = torch.lobpcg(square_data, k=eigvals_to_gen)
    return eig[0]
def eig_estimation(data,q):
    #cov = torch.cov(data.t())
    U, S, V = torch.pca_lowrank(data, q, center=True, niter=2)
    return S

# %%
matrix = np.load('/notebooks/10matrix5.npy', allow_pickle = True)
data = torch.from_numpy(arr)
print(data)
print(f"input matrix successfully loaded. It is of size {data.size()}")
"""
eig = eig_estimation(data,10)
print(eig)
print(eig.size())
print(torch.nansum(torch.sqrt(eig)))
"""
norm1 = l2norm(data)
#eig = get_sample_covariance_eigs(data)
#eig = personal_eig(matrix)
#eig.to('cpu')
#print(f"Eigenvalues: {eig}")
#norm = get_l2_norm(data)
#print(norm)
#print(eig.size())
#print(torch.nansum(torch.sqrt(eig)))
#saved = torch.nansum(torch.sqrt(eig))
#torch.save('square root', matrix)
#gaussian = get_gaussian(data)
#print(gaussian)
#print(gaussian)
#np.save('gausnoise.npy', gaussian)
#print(torch.nansum(torch.sqrt(gaussian)))
# Out:
# tensor([[ 0.0435,  0.0823,  0.0198,  ...,  0.0340,  0.1297, -0.0149]],
#        dtype=torch.float64)
# input matrix successfully loaded. It is of size torch.Size([1, 269722])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [8], line 11
#       4 print(f"input matrix successfully loaded. It is of size {data.size()}")
#       5 """
#       6 eig = eig_estimation(data,10)
#       7 print(eig)
#       8 print(eig.size())
#       9 print(torch.nansum(torch.sqrt(eig)))
#      10 """
# ---> 11 norm1 = l2norm(data)
#      12 #eig = get_sample_covariance_eigs(data)
#      13 #eig = personal_eig(matrix)
#      14 #eig.to('cpu')
#    (...)
#      25 #np.save('gausnoise.npy', gaussian)
#      26 #print(torch.nansum(torch.sqrt(gaussian)))
#
# Cell In [7], line 62, in l2norm(data)
#      60 for j in range(i+1, 10):
#      61     data1 = matrix[i]
# ---> 62     data2 = matrix[j]
#      63     print(np.shape(data1))
#      64     difference = data1 -data2
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
def generate_gaussian_noise(cov, noise_mult=1):
    U, S, V = torch.linalg.svd(cov)
    Sprime = torch.sqrt(S)
    Sprime *= torch.nansum(Sprime)
    Sprime = torch.sqrt(Sprime)

    noise = torch.randn(cov.size()[0], device=device)*noise_mult
   # print(noise.type())
    temp = torch.diag(Sprime).type(torch.FloatTensor)
    temp = temp.to(device)
  #  print(temp.type())
    noise = torch.matmul(noise, temp)
   # print(noise.type())
    noise = noise.type(torch.DoubleTensor)
    noise = torch.matmul(U.to(device), noise.to(device))
    return noise

"""
PRIMITIVE, DON'T KNOW IF RIGHT 
"""
def gen_noise2(data,q,noise_mult=0.2):
    U, S, V = torch.pca_lowrank(data, q, center=True, niter=2)
    Sprime = torch.sqrt(S)
    Sprime *= torch.nansum(Sprime)
    Sprime = torch.sqrt(Sprime)
   # cov = torch.cov(data.t())
    print("here")
    noise = torch.randn(data.size()[0], device=device)*noise_mult
    print(noise.size())
    temp = torch.diag(Sprime).type(torch.FloatTensor)
    temp = temp.to(device)
    noise = torch.matmul(noise, temp)
    print(noise.size())
    noise = noise.type(torch.DoubleTensor)
    noise = torch.matmul(V.to(device), noise.to(device))
    print(noise.size())
    return noise
    
def add_noise2(model, noise):
    model1 = model
    for param in model1.parameters():
        needed = param.numel()
        use, left = torch.split(noise, [needed, noise.numel()-needed])
        use1 =torch.reshape(use,param.size())
        noise1 = torch.nn.Parameter(param.cpu() + use1.cpu()).to(device)
        with torch.no_grad():
            param.copy_(noise1)
        noise = left
    return model1
def generate_noise(model, gaussian):
    #print(model.fc.weight)
    weights1, bias1, weights2, bias2 = torch.split(gaussian, [16384,64,640,10])
   # print(weights)
    #print(bias.size())
    #print(bias)
    #print(weights2)
    gaussianweights1 = torch.reshape(weights1, (64,256))
    gaussianweights2 = torch.reshape(weights2, (10, 64))
  #  print(gaussianweights2)
    model1 = model
    for name, param in model1.named_parameters():
        if(name == 'classifier.6.0.weight'):
            noise = torch.nn.Parameter(param.cpu() + gaussianweights1.cpu()).to(device)
            with torch.no_grad():
                param.copy_(noise)
        if(name == 'classifier.6.3.weight'):
            noise = torch.nn.Parameter(param.cpu() + gaussianweights2.cpu()).to(device)
            with torch.no_grad():
                param.copy_(noise)
        if(name == 'classifier.6.0.bias'):
            noise2 = torch.nn.Parameter(param.cpu() + bias1.cpu()).to(device)
            with torch.no_grad():
                param.copy_(noise2)
        if(name == 'classifier.6.3.bias'):
            noise2 = torch.nn.Parameter(param.cpu() + bias2.cpu()).to(device)
            with torch.no_grad():
                param.copy_(noise2)
    return model
"""
def generate_noise(model, gaussian):
    #print(model.fc.weight)
    weights, bias = torch.split(gaussian, [5120,10])
   # print(weights)
    #print(bias.size())
    #print(bias)
    
    gaussianweights = torch.reshape(weights, (10,512))
    noise = torch.nn.Parameter(model.fc.weight.cpu() + gaussianweights.cpu()).to(device)
    with torch.no_grad():
        model.fc.weight.copy_(noise)

    print(model.fc.weight)
    print(model.fc.bias)
    print(bias)
    
    noise2 = torch.nn.Parameter(model.fc.bias.cpu() + bias.cpu()).to(device)
    with torch.no_grad():
        model.fc.bias.copy_(noise2)
    
    #print(model.fc.bias)
    #print(model.fc.weight)  
    return model
"""
def test_model(model):
    test_loss = 0.0
    testloader = torch.utils.data.DataLoader(testset, shuffle=True, num_workers=2, batch_size = 20)
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    train_on_gpu = torch.cuda.is_available()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01)
    model.eval()
    # iterate over test data
    for data, target in testloader:
        # move tensors to GPU if CUDA is available
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update test loss 
        test_loss += loss.item()*data.size(0)
        # convert output probabilities to predicted class
        _, pred = torch.max(output, 1)    
        # compare predictions to true label
        correct_tensor = pred.eq(target.data.view_as(pred))
        correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
        # calculate test accuracy for each object class
        for i in range(20):
            label = target.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1
    # average test loss
    test_loss = test_loss/len(testloader.dataset)
    #Q print('Test Loss: {:.6f}\n'.format(test_loss))
    
    for i in range(10):
        if class_total[i] > 0:
            
            print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
              classes[i], 100 * class_correct[i] / class_total[i],
              np.sum(class_correct[i]), np.sum(class_total[i])))
        else:
            print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
    print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
    return np.sum(class_correct) / np.sum(class_total)

# %%
"""
data2 = gen_noise2(data,10)
model = resnet20()
model.load_state_dict(torch.load("/notebooks/test1"))
model.to(device)  
for name, param in model.named_parameters():
    if("linear" in name):
        print(param)
test_model(model)
model1 = add_noise2(model, data2)
for name, param in model.named_parameters():
    if("linear" in name):
        print(param)
test_model(model1)
"""
average1 = 0
average2 = 0
for i in range(10):
    print("trial " + str(i))
    data2 = gen_noise2(data,10)
#    print(gaussian.size())
    model = resnet20()
    model.load_state_dict(torch.load("/notebooks/test" + str(i+1)))
    model.to(device)
    average1 += test_model(model)
    model1 = add_noise2(model, data2)
    #print(test_model(model))
    average2 += test_model(model1)
print(average1/10)
print(average2/10)
# Out:
# trial 0
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 92% (929/1000)
# Test Accuracy of  bird: 80% (804/1000)
# Test Accuracy of   cat: 62% (625/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 75% (750/1000)
# Test Accuracy of  frog: 85% (858/1000)
# Test Accuracy of horse: 65% (657/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 80% (8014/10000)
# Test Accuracy of airplane: 72% (727/1000)
# Test Accuracy of automobile: 79% (799/1000)
# Test Accuracy of  bird: 52% (523/1000)
# Test Accuracy of   cat: 27% (278/1000)
# Test Accuracy of  deer: 72% (724/1000)
# Test Accuracy of   dog: 84% (844/1000)
# Test Accuracy of  frog: 68% (684/1000)
# Test Accuracy of horse: 44% (442/1000)
# Test Accuracy of  ship: 78% (781/1000)
# Test Accuracy of truck: 95% (954/1000)
#
# Test Accuracy (Overall): 67% (6756/10000)
# trial 1
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 82% (827/1000)
# Test Accuracy of automobile: 93% (934/1000)
# Test Accuracy of  bird: 82% (825/1000)
# Test Accuracy of   cat: 66% (661/1000)
# Test Accuracy of  deer: 72% (725/1000)
# Test Accuracy of   dog: 68% (682/1000)
# Test Accuracy of  frog: 82% (829/1000)
# Test Accuracy of horse: 86% (863/1000)
# Test Accuracy of  ship: 86% (865/1000)
# Test Accuracy of truck: 90% (900/1000)
#
# Test Accuracy (Overall): 81% (8111/10000)
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 82% (825/1000)
# Test Accuracy of  bird: 86% (862/1000)
# Test Accuracy of   cat: 52% (522/1000)
# Test Accuracy of  deer: 48% (485/1000)
# Test Accuracy of   dog: 57% (576/1000)
# Test Accuracy of  frog: 44% (443/1000)
# Test Accuracy of horse: 83% (830/1000)
# Test Accuracy of  ship: 81% (817/1000)
# Test Accuracy of truck: 69% (694/1000)
#
# Test Accuracy (Overall): 69% (6917/10000)
# trial 2
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 71% (716/1000)
# Test Accuracy of   cat: 62% (625/1000)
# Test Accuracy of  deer: 83% (834/1000)
# Test Accuracy of   dog: 77% (779/1000)
# Test Accuracy of  frog: 90% (908/1000)
# Test Accuracy of horse: 82% (827/1000)
# Test Accuracy of  ship: 86% (867/1000)
# Test Accuracy of truck: 83% (835/1000)
#
# Test Accuracy (Overall): 81% (8141/10000)
# Test Accuracy of airplane: 73% (737/1000)
# Test Accuracy of automobile: 88% (883/1000)
# Test Accuracy of  bird: 58% (587/1000)
# Test Accuracy of   cat: 53% (533/1000)
# Test Accuracy of  deer: 58% (589/1000)
# Test Accuracy of   dog: 35% (350/1000)
# Test Accuracy of  frog: 89% (891/1000)
# Test Accuracy of horse: 81% (810/1000)
# Test Accuracy of  ship: 78% (789/1000)
# Test Accuracy of truck: 79% (791/1000)
#
# Test Accuracy (Overall): 69% (6960/10000)
# trial 3
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 90% (907/1000)
# Test Accuracy of automobile: 90% (902/1000)
# Test Accuracy of  bird: 77% (772/1000)
# Test Accuracy of   cat: 65% (659/1000)
# Test Accuracy of  deer: 71% (719/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 83% (832/1000)
# Test Accuracy of  ship: 88% (884/1000)
# Test Accuracy of truck: 90% (902/1000)
#
# Test Accuracy (Overall): 81% (8176/10000)
# Test Accuracy of airplane: 92% (921/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 74% (748/1000)
# Test Accuracy of  deer: 70% (708/1000)
# Test Accuracy of   dog: 72% (723/1000)
# Test Accuracy of  frog: 73% (734/1000)
# Test Accuracy of horse: 88% (881/1000)
# Test Accuracy of  ship: 83% (831/1000)
# Test Accuracy of truck: 89% (890/1000)
#
# Test Accuracy (Overall): 80% (8083/10000)
# trial 4
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 87% (879/1000)
# Test Accuracy of automobile: 94% (941/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 75% (759/1000)
# Test Accuracy of  deer: 74% (743/1000)
# Test Accuracy of   dog: 66% (668/1000)
# Test Accuracy of  frog: 82% (823/1000)
# Test Accuracy of horse: 80% (807/1000)
# Test Accuracy of  ship: 90% (905/1000)
# Test Accuracy of truck: 86% (860/1000)
#
# Test Accuracy (Overall): 81% (8155/10000)
# Test Accuracy of airplane: 69% (695/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 68% (681/1000)
# Test Accuracy of   cat: 51% (518/1000)
# Test Accuracy of  deer: 76% (763/1000)
# Test Accuracy of   dog: 78% (787/1000)
# Test Accuracy of  frog: 75% (751/1000)
# Test Accuracy of horse: 57% (573/1000)
# Test Accuracy of  ship: 81% (813/1000)
# Test Accuracy of truck: 81% (819/1000)
#
# Test Accuracy (Overall): 72% (7293/10000)
# trial 5
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 81% (815/1000)
# Test Accuracy of automobile: 91% (918/1000)
# Test Accuracy of  bird: 71% (719/1000)
# Test Accuracy of   cat: 68% (682/1000)
# Test Accuracy of  deer: 75% (759/1000)
# Test Accuracy of   dog: 75% (751/1000)
# Test Accuracy of  frog: 83% (832/1000)
# Test Accuracy of horse: 86% (864/1000)
# Test Accuracy of  ship: 88% (884/1000)
# Test Accuracy of truck: 89% (897/1000)
#
# Test Accuracy (Overall): 81% (8121/10000)
# Test Accuracy of airplane: 75% (757/1000)
# Test Accuracy of automobile: 83% (834/1000)
# Test Accuracy of  bird: 82% (820/1000)
# Test Accuracy of   cat: 64% (646/1000)
# Test Accuracy of  deer: 77% (774/1000)
# Test Accuracy of   dog: 65% (651/1000)
# Test Accuracy of  frog: 75% (756/1000)
# Test Accuracy of horse: 87% (876/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 65% (658/1000)
#
# Test Accuracy (Overall): 76% (7673/10000)
# trial 6
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 85% (855/1000)
# Test Accuracy of automobile: 93% (931/1000)
# Test Accuracy of  bird: 78% (785/1000)
# Test Accuracy of   cat: 64% (649/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 76% (767/1000)
# Test Accuracy of  frog: 81% (818/1000)
# Test Accuracy of horse: 85% (856/1000)
# Test Accuracy of  ship: 92% (926/1000)
# Test Accuracy of truck: 90% (903/1000)
#
# Test Accuracy (Overall): 82% (8261/10000)
# Test Accuracy of airplane: 76% (765/1000)
# Test Accuracy of automobile: 88% (882/1000)
# Test Accuracy of  bird: 69% (697/1000)
# Test Accuracy of   cat: 46% (460/1000)
# Test Accuracy of  deer: 77% (774/1000)
# Test Accuracy of   dog: 87% (878/1000)
# Test Accuracy of  frog: 78% (781/1000)
# Test Accuracy of horse: 73% (730/1000)
# Test Accuracy of  ship: 93% (931/1000)
# Test Accuracy of truck: 95% (958/1000)
#
# Test Accuracy (Overall): 78% (7856/10000)
# trial 7
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 81% (812/1000)
# Test Accuracy of automobile: 92% (925/1000)
# Test Accuracy of  bird: 78% (783/1000)
# Test Accuracy of   cat: 67% (674/1000)
# Test Accuracy of  deer: 86% (866/1000)
# Test Accuracy of   dog: 66% (662/1000)
# Test Accuracy of  frog: 83% (837/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 88% (889/1000)
# Test Accuracy of truck: 89% (894/1000)
#
# Test Accuracy (Overall): 81% (8156/10000)
# Test Accuracy of airplane: 80% (802/1000)
# Test Accuracy of automobile: 94% (949/1000)
# Test Accuracy of  bird: 67% (670/1000)
# Test Accuracy of   cat: 43% (435/1000)
# Test Accuracy of  deer: 57% (574/1000)
# Test Accuracy of   dog: 34% (347/1000)
# Test Accuracy of  frog: 92% (927/1000)
# Test Accuracy of horse: 53% (537/1000)
# Test Accuracy of  ship: 64% (649/1000)
# Test Accuracy of truck: 69% (694/1000)
#
# Test Accuracy (Overall): 65% (6584/10000)
# trial 8
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 82% (825/1000)
# Test Accuracy of automobile: 91% (914/1000)
# Test Accuracy of  bird: 75% (753/1000)
# Test Accuracy of   cat: 80% (807/1000)
# Test Accuracy of  deer: 73% (738/1000)
# Test Accuracy of   dog: 62% (622/1000)
# Test Accuracy of  frog: 84% (847/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 80% (8085/10000)
# Test Accuracy of airplane: 79% (796/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 67% (676/1000)
# Test Accuracy of   cat: 66% (668/1000)
# Test Accuracy of  deer: 51% (516/1000)
# Test Accuracy of   dog: 58% (589/1000)
# Test Accuracy of  frog: 90% (901/1000)
# Test Accuracy of horse: 60% (607/1000)
# Test Accuracy of  ship: 84% (840/1000)
# Test Accuracy of truck: 73% (739/1000)
#
# Test Accuracy (Overall): 72% (7225/10000)
# trial 9
# here
# torch.Size([10])
# torch.Size([10])
# torch.Size([269722])
# Test Accuracy of airplane: 83% (831/1000)
# Test Accuracy of automobile: 88% (886/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 70% (701/1000)
# Test Accuracy of  deer: 73% (735/1000)
# Test Accuracy of   dog: 72% (728/1000)
# Test Accuracy of  frog: 90% (908/1000)
# Test Accuracy of horse: 82% (827/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 88% (887/1000)
#
# Test Accuracy (Overall): 81% (8113/10000)
# Test Accuracy of airplane: 66% (665/1000)
# Test Accuracy of automobile: 82% (828/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 78% (783/1000)
# Test Accuracy of  deer: 53% (538/1000)
# Test Accuracy of   dog: 64% (648/1000)
# Test Accuracy of  frog: 75% (757/1000)
# Test Accuracy of horse: 80% (807/1000)
# Test Accuracy of  ship: 94% (949/1000)
# Test Accuracy of truck: 90% (909/1000)
#
# Test Accuracy (Overall): 76% (7623/10000)
# 0.81333
# 0.7297

# %%
#gaussian = np.load('gausnoise.npy', allow_pickle = true)
average1 = 0
average2 = 0
data2 = gen_noise2(data,10)
for i in range(30):
    print("trial " + str(i))
    gaussian = generate_gaussian_noise(cov)
#    print(gaussian.size())
    model = torchvision.models.vgg19(pretrained = False)
    model.classifier[5] = nn.Sequential(
                    nn.Dropout(p=0.5, inplace=False),
                    nn.Linear(4096, 512, bias = True), 
                    nn.ReLU(), 
                    nn.Dropout(0.6, inplace=False),
                    nn.Linear(512, 256, bias = True),
                    nn.ReLU(),
                    nn.Dropout(p=0.5, inplace=False))
    for parameter in model.parameters():
        parameter.requires_grad = False
    model.classifier[6] = nn.Sequential(
                    nn.Linear(256, 64, bias = True),
                    nn.ReLU(),
                    nn.Dropout(p=0.5, inplace=False),
                    nn.Linear(64, 10))
    model.load_state_dict(torch.load("/notebooks/test" + str(i+1)))
    model.to(device)
    average1 += test_model(model)
    model1 = generate_noise(model, gaussian)
    #print(test_model(model))
    average2 += test_model(model1)
print(average1/30)
print(average2/30)
